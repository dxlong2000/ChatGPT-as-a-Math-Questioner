# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/
# !git clone -q https://github.com/huggingface/transformers
# %cd transformers
# !pip install -q .
# Out:
# /content
# /content/transformers
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 224.5/224.5 kB 19.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 99.6 MB/s eta 0:00:00
# ...

# %%
# !cp '/content/drive/MyDrive/AI for Education/MATH Dataset/Context_Aware_Ans_Unaware_Finetune/train_ans_unaware_finetune_MATH.csv' /content/transformers/examples/pytorch/summarization
# !cp '/content/drive/MyDrive/AI for Education/MATH Dataset/Context_Aware_Ans_Unaware_Finetune/test_ans_unaware_finetune_MATH.csv' /content/transformers/examples/pytorch/summarization

# %%
# %cd /content/transformers/examples/pytorch/summarization
# !pip install -r requirements.txt

# %% [markdown]
# ## <h1> 1. T5

# %%
# !python3 run_summarization.py \
    --model_name_or_path t5-base \
    --do_train \
    --do_eval \
    --do_predict \
    --train_file 'train_ans_unaware_finetune_MATH.csv' \
    --validation_file 'test_ans_unaware_finetune_MATH.csv' \
    --test_file 'test_ans_unaware_finetune_MATH.csv' \
    --text_column text \
    --summary_column headlines \
    --source_prefix "generate a math question from context: " \
    --output_dir  'output-T5' \
    --logging_dir  'output-T5' \
    --per_device_train_batch_size=2 \
    --per_device_eval_batch_size=2 \
    --gradient_accumulation_steps=2 \
    --predict_with_generate=True \
    --learning_rate=0.00002 \
    --num_beams=5 \
    --max_steps=1000 \
    --save_steps=500 \
    --eval_steps=500 \
    --evaluation_strategy steps \
    --load_best_model \
    --overwrite_output_dir
# Out:
# 2023-05-17 08:23:31.988006: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 05/17/2023 08:23:34 - WARNING - __main__ - Process rank: 0, device: cuda:0, n_gpu: 1distributed training: True, 16-bits training: False
# 05/17/2023 08:23:34 - INFO - __main__ - Training/evaluation parameters Seq2SeqTrainingArguments(
# _n_gpu=1,
# adafactor=False,
# adam_beta1=0.9,
# adam_beta2=0.999,
# adam_epsilon=1e-08,
# auto_find_batch_size=False,
# bf16=False,
# bf16_full_eval=False,
# data_seed=None,
# dataloader_drop_last=False,
# dataloader_num_workers=0,
# dataloader_pin_memory=True,
# ddp_backend=None,
# ddp_bucket_cap_mb=None,
# ddp_find_unused_parameters=None,
# ddp_timeout=1800,
# debug=[],
# deepspeed=None,
# disable_tqdm=False,
# do_eval=True,
# do_predict=True,
# do_train=True,
# eval_accumulation_steps=None,
# eval_delay=0,
# eval_steps=500,
# evaluation_strategy=steps,
# fp16=False,
# fp16_backend=auto,
# fp16_full_eval=False,
# ...

# %% [markdown]
# ## Resume training

# %%
# %cd /content/transformers/examples/pytorch/summarization
# !mkdir output-T5
# Out:
# /content/transformers/examples/pytorch/summarization

# %%
# !cp -r /content/drive/MyDrive/T5_ANS_UNAW_MATH/checkpoint-8000 /content/transformers/examples/pytorch/summarization/output-T5/

# %%
# !rm -r /content/transformers/examples/pytorch/summarization/output-T5/checkpoint-2500

# %%
# !python3 run_summarization.py \
    --model_name_or_path t5-base \
    --do_train \
    --do_eval \
    --do_predict \
    --train_file 'train_ans_unaware_finetune_MATH.csv' \
    --validation_file 'test_ans_unaware_finetune_MATH.csv' \
    --test_file 'test_ans_unaware_finetune_MATH.csv' \
    --text_column text \
    --summary_column headlines \
    --source_prefix "generate a math question from context: " \
    --output_dir  'output-T5' \
    --logging_dir  'output-T5' \
    --per_device_train_batch_size=2 \
    --per_device_eval_batch_size=2 \
    --gradient_accumulation_steps=2 \
    --predict_with_generate=True \
    --learning_rate=0.00002 \
    --num_beams=5 \
    --max_steps=10000 \
    --save_steps=500 \
    --eval_steps=500 \
    --evaluation_strategy steps \
    --load_best_model
# Out:
# Streaming output truncated to the last 5000 lines.
#  38% 705/1869 [14:06<08:20,  2.33it/s]
#  38% 706/1869 [14:06<08:28,  2.28it/s]
#  38% 707/1869 [14:07<08:24,  2.30it/s]
#  38% 708/1869 [14:07<09:18,  2.08it/s]
#  38% 709/1869 [14:08<10:27,  1.85it/s]
#  38% 710/1869 [14:09<11:59,  1.61it/s]
#  38% 711/1869 [14:09<11:56,  1.62it/s]
#  38% 712/1869 [14:10<12:00,  1.60it/s]
#  38% 713/1869 [14:11<12:10,  1.58it/s]
#  38% 714/1869 [14:11<12:36,  1.53it/s]
#  38% 715/1869 [14:12<12:50,  1.50it/s]
#  38% 716/1869 [14:13<13:15,  1.45it/s]
#  38% 717/1869 [14:14<13:35,  1.41it/s]
#  38% 718/1869 [14:14<14:16,  1.34it/s]
#  38% 719/1869 [14:15<14:16,  1.34it/s]
#  39% 720/1869 [14:16<15:45,  1.22it/s]
#  39% 721/1869 [14:17<13:22,  1.43it/s]
#  39% 722/1869 [14:17<12:21,  1.55it/s]
#  39% 723/1869 [14:18<12:20,  1.55it/s]
#  39% 724/1869 [14:18<10:56,  1.74it/s]
#  39% 725/1869 [14:19<10:04,  1.89it/s]
#  39% 726/1869 [14:19<10:24,  1.83it/s]
#  39% 727/1869 [14:20<09:33,  1.99it/s]
# ...

# %%
# %cd /content/transformers/examples/pytorch/summarization/output-T5
# !cp all_results.json /content/drive/MyDrive/T5_ANS_UNAW_MATH
# !cp README.md /content/drive/MyDrive/T5_ANS_UNAW_MATH
# !cp eval_results.json /content/drive/MyDrive/T5_ANS_UNAW_MATH
# !cp generated_predictions.txt /content/drive/MyDrive/T5_ANS_UNAW_MATH
# !cp generation_config.json /content/drive/MyDrive/T5_ANS_UNAW_MATH
# !cp config.json /content/drive/MyDrive/T5_ANS_UNAW_MATH
# !cp predict_results.json /content/drive/MyDrive/T5_ANS_UNAW_MATH
# !cp special_tokens_map.json /content/drive/MyDrive/T5_ANS_UNAW_MATH
# !cp spiece.model /content/drive/MyDrive/T5_ANS_UNAW_MATH
# !cp tokenizer.json /content/drive/MyDrive/T5_ANS_UNAW_MATH
# !cp tokenizer_config.json /content/drive/MyDrive/T5_ANS_UNAW_MATH
# !cp train_results.json /content/drive/MyDrive/T5_ANS_UNAW_MATH
# !cp trainer_state.json /content/drive/MyDrive/T5_ANS_UNAW_MATH
# !cp training_args.bin /content/drive/MyDrive/T5_ANS_UNAW_MATH
# !cp pytorch_model.bin /content/drive/MyDrive/T5_ANS_UNAW_MATH
# Out:
# /content/transformers/examples/pytorch/summarization/output-T5

# %%
with open("generated_predictions.txt", "r") as file:
    cnt = 0
    for line in file:
        cnt += 1
    print(cnt)
# Out:
# 3737

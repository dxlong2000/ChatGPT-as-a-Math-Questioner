# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/
# !git clone -q https://github.com/huggingface/transformers
# %cd transformers
# !pip install -q .
# Out:
# /content
# /content/transformers
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 224.5/224.5 kB 18.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 109.8 MB/s eta 0:00:00
# ...

# %%
# !cp '/content/drive/MyDrive/AI for Education/MATH Dataset/Context_Aware_Answer_Aware_Finetune/train_and_val.csv' /content/transformers/examples/pytorch/summarization
# !cp '/content/drive/MyDrive/AI for Education/MATH Dataset/Context_Aware_Answer_Aware_Finetune/test.csv' /content/transformers/examples/pytorch/summarization

# %%
# %cd /content/transformers/examples/pytorch/summarization
# !pip install -r requirements.txt
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 149.6/149.6 kB 19.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 114.5/114.5 kB 11.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 268.8/268.8 kB 30.3 MB/s eta 0:00:00
# ...
#   Created wheel for rouge-score: filename=rouge_score-0.1.2-py3-none-any.whl size=24954 sha256=931931954d8d83e44b4435751f25832d2f6d8db47326e43a35cbe261fa3a03fe
#   Stored in directory: /root/.cache/pip/wheels/5f/dd/89/461065a73be61a532ff8599a28e9beef17985c9e9c31e541b4
# Successfully built rouge-score
# ...

# %% [markdown]
# ## <h1> 1. BART

# %%
# !python3 run_summarization.py \
    --model_name_or_path facebook/bart-base \
    --do_train \
    --do_eval \
    --do_predict \
    --train_file 'train_and_val.csv' \
    --validation_file 'test.csv' \
    --test_file 'test.csv' \
    --text_column text \
    --summary_column headlines \
    --source_prefix "generate a math question from context: " \
    --output_dir  'output-bart' \
    --logging_dir  'output-bart' \
    --per_device_train_batch_size=2 \
    --per_device_eval_batch_size=2 \
    --gradient_accumulation_steps=2 \
    --predict_with_generate=True \
    --learning_rate=0.00005 \
    --num_beams=5 \
    --max_steps=5000 \
    --save_steps=500 \
    --eval_steps=500 \
    --evaluation_strategy steps \
    --load_best_model \
    --overwrite_output_dir

# %%
# !cp -r /content/transformers/examples/pytorch/summarization/output-bart/checkpoint-500 /content/drive/MyDrive/BART_TEMP/
# !cp -r /content/transformers/examples/pytorch/summarization/output-bart/checkpoint-1000 /content/drive/MyDrive/BART_TEMP/
# !cp -r /content/transformers/examples/pytorch/summarization/output-bart/checkpoint-1500 /content/drive/MyDrive/BART_TEMP/
# !cp -r /content/transformers/examples/pytorch/summarization/output-bart/checkpoint-2000 /content/drive/MyDrive/BART_TEMP/
# !cp -r /content/transformers/examples/pytorch/summarization/output-bart/checkpoint-2500 /content/drive/MyDrive/BART_TEMP/
# !cp -r /content/transformers/examples/pytorch/summarization/output-bart/checkpoint-3000 /content/drive/MyDrive/BART_TEMP/
# !cp -r /content/transformers/examples/pytorch/summarization/output-bart/checkpoint-3500 /content/drive/MyDrive/BART_TEMP/
# !cp -r /content/transformers/examples/pytorch/summarization/output-bart/checkpoint-4000 /content/drive/MyDrive/BART_TEMP/
# !cp -r /content/transformers/examples/pytorch/summarization/output-bart/checkpoint-4500 /content/drive/MyDrive/BART_TEMP/
# !cp -r /content/transformers/examples/pytorch/summarization/output-bart/checkpoint-5000 /content/drive/MyDrive/BART_TEMP/output-bart

# %% [markdown]
# ## Resume training

# %%
# %cd /content/transformers/examples/pytorch/summarization
# !mkdir output-bart
# Out:
# /content/transformers/examples/pytorch/summarization

# %%
# !cp -r /content/drive/MyDrive/BART_TEMP/output-bart/checkpoint-10000 /content/transformers/examples/pytorch/summarization/output-bart/

# %%
# !rm -r /content/transformers/examples/pytorch/summarization/output-T5/checkpoint-2500

# %%
# !python3 run_summarization.py \
    --model_name_or_path facebook/bart-base \
    --do_train \
    --do_eval \
    --do_predict \
    --train_file 'train_and_val.csv' \
    --validation_file 'test.csv' \
    --test_file 'test.csv' \
    --text_column text \
    --summary_column headlines \
    --source_prefix "generate a math question from context: " \
    --output_dir  'output-bart' \
    --logging_dir  'output-bart' \
    --per_device_train_batch_size=2 \
    --per_device_eval_batch_size=2 \
    --gradient_accumulation_steps=2 \
    --predict_with_generate=True \
    --learning_rate=0.00005 \
    --num_beams=5 \
    --max_steps=10000 \
    --save_steps=500 \
    --eval_steps=500 \
    --evaluation_strategy steps \
    --load_best_model
# Out:
# 2023-05-07 06:48:51.695433: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 05/07/2023 06:48:54 - WARNING - __main__ - Process rank: 0, device: cuda:0, n_gpu: 1distributed training: True, 16-bits training: False
# 05/07/2023 06:48:54 - INFO - __main__ - Training/evaluation parameters Seq2SeqTrainingArguments(
# _n_gpu=1,
# adafactor=False,
# adam_beta1=0.9,
# adam_beta2=0.999,
# adam_epsilon=1e-08,
# auto_find_batch_size=False,
# bf16=False,
# bf16_full_eval=False,
# data_seed=None,
# dataloader_drop_last=False,
# dataloader_num_workers=0,
# dataloader_pin_memory=True,
# ddp_backend=None,
# ddp_bucket_cap_mb=None,
# ddp_find_unused_parameters=None,
# ddp_timeout=1800,
# debug=[],
# deepspeed=None,
# disable_tqdm=False,
# do_eval=True,
# do_predict=True,
# do_train=True,
# eval_accumulation_steps=None,
# eval_delay=0,
# eval_steps=500,
# evaluation_strategy=steps,
# fp16=False,
# fp16_backend=auto,
# fp16_full_eval=False,
# ...

# %%
import os
for x in os.listdir("/content/transformers/examples/pytorch/summarization/output-bart"):
  if x[:5] not in ["check","event"]:
    print("!cp", x, " /content/drive/MyDrive/BART_TEMP")
# Out:
# !cp tokenizer.json  /content/drive/MyDrive/BART_TEMP
# !cp generation_config.json  /content/drive/MyDrive/BART_TEMP
# !cp all_results.json  /content/drive/MyDrive/BART_TEMP
# !cp config.json  /content/drive/MyDrive/BART_TEMP
# !cp 1683442165.1282334  /content/drive/MyDrive/BART_TEMP
# !cp predict_results.json  /content/drive/MyDrive/BART_TEMP
# !cp eval_results.json  /content/drive/MyDrive/BART_TEMP
# !cp training_args.bin  /content/drive/MyDrive/BART_TEMP
# !cp trainer_state.json  /content/drive/MyDrive/BART_TEMP
# !cp vocab.json  /content/drive/MyDrive/BART_TEMP
# !cp special_tokens_map.json  /content/drive/MyDrive/BART_TEMP
# !cp tokenizer_config.json  /content/drive/MyDrive/BART_TEMP
# !cp pytorch_model.bin  /content/drive/MyDrive/BART_TEMP
# !cp README.md  /content/drive/MyDrive/BART_TEMP
# !cp generated_predictions.txt  /content/drive/MyDrive/BART_TEMP
# !cp train_results.json  /content/drive/MyDrive/BART_TEMP
# !cp merges.txt  /content/drive/MyDrive/BART_TEMP

# %%
# %cd /content/transformers/examples/pytorch/summarization/output-bart
# !cp tokenizer.json  /content/drive/MyDrive/BART_TEMP
# !cp generation_config.json  /content/drive/MyDrive/BART_TEMP
# !cp all_results.json  /content/drive/MyDrive/BART_TEMP
# !cp config.json  /content/drive/MyDrive/BART_TEMP
# !cp predict_results.json  /content/drive/MyDrive/BART_TEMP
# !cp eval_results.json  /content/drive/MyDrive/BART_TEMP
# !cp training_args.bin  /content/drive/MyDrive/BART_TEMP
# !cp trainer_state.json  /content/drive/MyDrive/BART_TEMP
# !cp vocab.json  /content/drive/MyDrive/BART_TEMP
# !cp special_tokens_map.json  /content/drive/MyDrive/BART_TEMP
# !cp tokenizer_config.json  /content/drive/MyDrive/BART_TEMP
# !cp pytorch_model.bin  /content/drive/MyDrive/BART_TEMP
# !cp README.md  /content/drive/MyDrive/BART_TEMP
# !cp generated_predictions.txt  /content/drive/MyDrive/BART_TEMP
# !cp train_results.json  /content/drive/MyDrive/BART_TEMP
# !cp merges.txt  /content/drive/MyDrive/BART_TEMP
# Out:
# /content/transformers/examples/pytorch/summarization/output-bart

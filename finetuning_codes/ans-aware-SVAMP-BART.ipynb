# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !rm -r /content/transformers

# %%
# %cd /content/
# !git clone https://github.com/huggingface/transformers
# %cd transformers
# !pip install .

# %% [markdown]
# <h1> 1. BART

# %%
# !cp "/content/drive/MyDrive/NLP Research with Prof. Luu/AI for Education/SVAMP/train_merge.csv" /content/transformers/examples/pytorch/summarization
# !cp "/content/drive/MyDrive/NLP Research with Prof. Luu/AI for Education/SVAMP/val.csv" /content/transformers/examples/pytorch/summarization
# !cp "/content/drive/MyDrive/NLP Research with Prof. Luu/AI for Education/SVAMP/test.csv" /content/transformers/examples/pytorch/summarization

# %%
# %cd /content/transformers/examples/pytorch/summarization
# !pip install -r requirements.txt

# %%
# start training
# !python3 run_summarization.py \
    --model_name_or_path facebook/bart-base \
    --do_train \
    --do_eval \
    --do_predict \
    --train_file 'train_merge.csv' \
    --validation_file 'test.csv' \
    --test_file 'test.csv' \
    --text_column text \
    --summary_column headlines \
    --source_prefix "generate a math question from context: " \
    --output_dir  'output-bart' \
    --logging_dir  'output-bart' \
    --per_device_train_batch_size=2 \
    --per_device_eval_batch_size=2 \
    --gradient_accumulation_steps=2 \
    --predict_with_generate=True \
    --learning_rate=0.00001 \
    --num_beams=5 \
    --max_steps=15000 \
    --save_steps=500 \
    --eval_steps=500 \
    --evaluation_strategy steps \
    --load_best_model \
    --overwrite_output_dir
# Out:
# 2023-04-30 14:52:52.226796: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 04/30/2023 14:52:55 - WARNING - __main__ - Process rank: 0, device: cuda:0, n_gpu: 1distributed training: True, 16-bits training: False
# 04/30/2023 14:52:55 - INFO - __main__ - Training/evaluation parameters Seq2SeqTrainingArguments(
# _n_gpu=1,
# adafactor=False,
# adam_beta1=0.9,
# adam_beta2=0.999,
# adam_epsilon=1e-08,
# auto_find_batch_size=False,
# bf16=False,
# bf16_full_eval=False,
# data_seed=None,
# dataloader_drop_last=False,
# dataloader_num_workers=0,
# dataloader_pin_memory=True,
# ddp_bucket_cap_mb=None,
# ddp_find_unused_parameters=None,
# ddp_timeout=1800,
# debug=[],
# deepspeed=None,
# disable_tqdm=False,
# do_eval=True,
# do_predict=True,
# do_train=True,
# eval_accumulation_steps=None,
# eval_delay=0,
# eval_steps=500,
# evaluation_strategy=steps,
# fp16=False,
# fp16_backend=auto,
# fp16_full_eval=False,
# fp16_opt_level=O1,
# fsdp=[],
# ...

# %%
# !rm -r /content/transformers/examples/pytorch/summarization/output-T5/checkpoint-75

# %%
# resume training
# !python3 run_summarization.py \
    --model_name_or_path t5-base \
    --do_train \
    --do_eval \
    --do_predict \
    --train_file 'train_merge.csv' \
    --validation_file 'test.csv' \
    --test_file 'test.csv' \
    --text_column text \
    --summary_column headlines \
    --source_prefix "generate a math question from context: " \
    --output_dir  'output-T5' \
    --logging_dir  'output-T5' \
    --per_device_train_batch_size=2 \
    --per_device_eval_batch_size=2 \
    --gradient_accumulation_steps=2 \
    --predict_with_generate=True \
    --learning_rate=0.00001 \
    --num_beams=5 \
    --max_steps=15000 \
    --save_steps=500 \
    --eval_steps=500 \
    --evaluation_strategy steps \
    --load_best_model

# %%
# !cp -r /content/transformers/examples/pytorch/summarization/output-T5/checkpoint-500 /content/drive/MyDrive/SVAMP_TEMP

# %%
# %cd /content/transformers/examples/pytorch/summarization/output-bart
# !cp all_results.json /content/drive/MyDrive/SVAMP_TEMP
# !cp README.md /content/drive/MyDrive/SVAMP_TEMP
# !cp eval_results.json /content/drive/MyDrive/SVAMP_TEMP
# !cp generated_predictions.txt /content/drive/MyDrive/SVAMP_TEMP
# !cp generation_config.json /content/drive/MyDrive/SVAMP_TEMP
# !cp merges.txt /content/drive/MyDrive/SVAMP_TEMP
# !cp predict_results.json /content/drive/MyDrive/SVAMP_TEMP
# !cp special_tokens_map.json /content/drive/MyDrive/SVAMP_TEMP
# !cp spiece.model /content/drive/MyDrive/SVAMP_TEMP
# !cp tokenizer.json /content/drive/MyDrive/SVAMP_TEMP
# !cp tokenizer_config.json /content/drive/MyDrive/SVAMP_TEMP
# !cp train_results.json /content/drive/MyDrive/SVAMP_TEMP
# !cp trainer_state.json /content/drive/MyDrive/SVAMP_TEMP
# !cp training_args.bin /content/drive/MyDrive/SVAMP_TEMP
# !cp pytorch_model.bin /content/drive/MyDrive/SVAMP_TEMP
# !cp vocab.json /content/drive/MyDrive/SVAMP_TEMP
# !cp config.json /content/drive/MyDrive/SVAMP_TEMP
# !cp 'events.out.tfevents.1682866391.b6fc9148fa3e.3921.0' /content/drive/MyDrive/SVAMP_TEMP
# !cp 'events.out.tfevents.1682869598.b6fc9148fa3e.3921.2' /content/drive/MyDrive/SVAMP_TEMP
# !cp '1682866391.1117432/events.out.tfevents.1682866391.b6fc9148fa3e.3921.1' /content/drive/MyDrive/SVAMP_TEMP
# Out:
# /content/transformers/examples/pytorch/summarization/output-bart
# cp: cannot stat 'spiece.model': No such file or directory

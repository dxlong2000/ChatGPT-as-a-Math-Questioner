# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## SVAMP

# %%
import pandas as pd 
train = pd.read_csv("/content/drive/MyDrive/AI for Education/SVAMP/train_merge.csv")
test = pd.read_csv("/content/drive/MyDrive/AI for Education/SVAMP/test.csv")

# %%
train["text"] = "Context: " + train["Body"]
test["text"] = "Context: " + test["Body"]

# %%
train.to_csv("/content/drive/MyDrive/AI for Education/SVAMP/train_ans_unaware_finetune_svamp.csv")
test.to_csv("/content/drive/MyDrive/AI for Education/SVAMP/test_ans_unaware_finetune_svamp.csv")

# %% [markdown]
# ## GSM8K

# %%
import pandas as pd 
train = pd.read_csv("/content/drive/MyDrive/AI for Education/GSM8K/train.csv")
test = pd.read_csv("/content/drive/MyDrive/AI for Education/GSM8K/test.csv")

# %%
train

# %%
train["text"] = "Context: " + train["context"]
test["text"] = "Context: " + test["context"]

# %%
train.to_csv("/content/drive/MyDrive/AI for Education/GSM8K/train_ans_unaware_finetune_GSM8K.csv")
test.to_csv("/content/drive/MyDrive/AI for Education/GSM8K/test_ans_unaware_finetune_GSM8K.csv")

# %% [markdown]
# ## MATH

# %%
import pandas as pd
train = pd.read_csv("/content/drive/MyDrive/AI_Education/MATH Dataset/Context_Aware_Answer_Aware_Finetune/train_and_val.csv")
test = pd.read_csv("/content/drive/MyDrive/AI_Education/MATH Dataset/Context_Aware_Answer_Aware_Finetune/test.csv")

# %%
train["text"] = "Context: " + train["context"]
test["text"] = "Context: " + test["context"]

# %%
train.to_csv("/content/drive/MyDrive/AI_Education/MATH Dataset/Context_Aware_Ans_Unaware_Finetune/train_ans_unaware_finetune_MATH.csv")
test.to_csv("/content/drive/MyDrive/AI_Education/MATH Dataset/Context_Aware_Ans_Unaware_Finetune/test_ans_unaware_finetune_MATH.csv")

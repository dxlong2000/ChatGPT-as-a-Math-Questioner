# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !rm -r /content/transformers
# Out:
# rm: cannot remove '/content/transformers': No such file or directory

# %%
# %cd /content/
# !git clone https://github.com/huggingface/transformers
# %cd transformers
# !pip install .

# %% [markdown]
# <h1> 1. BART

# %%
# !cp "/content/drive/MyDrive/AI for Education/SVAMP/train_ans_unaware_finetune_svamp.csv" /content/transformers/examples/pytorch/summarization
# !cp "/content/drive/MyDrive/AI for Education/SVAMP/test_ans_unaware_finetune_svamp.csv" /content/transformers/examples/pytorch/summarization

# %%
# %cd /content/transformers/examples/pytorch/summarization
# !pip install -r requirements.txt

# %%
# start training
# !python3 run_summarization.py \
    --model_name_or_path facebook/bart-base \
    --do_train \
    --do_eval \
    --do_predict \
    --train_file 'train_ans_unaware_finetune_svamp.csv' \
    --validation_file 'test_ans_unaware_finetune_svamp.csv' \
    --test_file 'test_ans_unaware_finetune_svamp.csv' \
    --text_column text \
    --summary_column headlines \
    --source_prefix "generate a math question from context: " \
    --output_dir  'output-bart' \
    --logging_dir  'output-bart' \
    --per_device_train_batch_size=2 \
    --per_device_eval_batch_size=2 \
    --gradient_accumulation_steps=2 \
    --predict_with_generate=True \
    --learning_rate=0.00001 \
    --num_beams=5 \
    --max_steps=15000 \
    --save_steps=500 \
    --eval_steps=500 \
    --evaluation_strategy steps \
    --load_best_model \
    --overwrite_output_dir
# Out:
# 2023-05-08 12:17:58.155740: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 05/08/2023 12:18:01 - WARNING - __main__ - Process rank: 0, device: cuda:0, n_gpu: 1distributed training: True, 16-bits training: False
# 05/08/2023 12:18:01 - INFO - __main__ - Training/evaluation parameters Seq2SeqTrainingArguments(
# _n_gpu=1,
# adafactor=False,
# adam_beta1=0.9,
# adam_beta2=0.999,
# adam_epsilon=1e-08,
# auto_find_batch_size=False,
# bf16=False,
# bf16_full_eval=False,
# data_seed=None,
# dataloader_drop_last=False,
# dataloader_num_workers=0,
# dataloader_pin_memory=True,
# ddp_backend=None,
# ddp_bucket_cap_mb=None,
# ddp_find_unused_parameters=None,
# ddp_timeout=1800,
# debug=[],
# deepspeed=None,
# disable_tqdm=False,
# do_eval=True,
# do_predict=True,
# do_train=True,
# eval_accumulation_steps=None,
# eval_delay=0,
# eval_steps=500,
# evaluation_strategy=steps,
# fp16=False,
# fp16_backend=auto,
# fp16_full_eval=False,
# ...

# %%
# !rm -r /content/transformers/examples/pytorch/summarization/output-T5/checkpoint-75

# %%
# resume training
# !python3 run_summarization.py \
    --model_name_or_path t5-base \
    --do_train \
    --do_eval \
    --do_predict \
    --train_file 'train_ans_unaware_finetune_svamp.csv' \
    --validation_file 'test_ans_unaware_finetune_svamp.csv' \
    --test_file 'test_ans_unaware_finetune_svamp.csv' \
    --text_column text \
    --summary_column headlines \
    --source_prefix "generate a math question from context: " \
    --output_dir  'output-T5' \
    --logging_dir  'output-T5' \
    --per_device_train_batch_size=2 \
    --per_device_eval_batch_size=2 \
    --gradient_accumulation_steps=2 \
    --predict_with_generate=True \
    --learning_rate=0.00001 \
    --num_beams=5 \
    --max_steps=15000 \
    --save_steps=500 \
    --eval_steps=500 \
    --evaluation_strategy steps \
    --load_best_model

# %%
import os
for x in os.listdir("/content/transformers/examples/pytorch/summarization/output-bart"):
  if x[:5] not in ["check", "event"]:
    print("!cp", x, "/content/drive/MyDrive/T5_ANS_UNAW_SVAMP")
# Out:
# !cp tokenizer.json /content/drive/MyDrive/T5_ANS_UNAW_SVAMP
# !cp generation_config.json /content/drive/MyDrive/T5_ANS_UNAW_SVAMP
# !cp all_results.json /content/drive/MyDrive/T5_ANS_UNAW_SVAMP
# !cp config.json /content/drive/MyDrive/T5_ANS_UNAW_SVAMP
# !cp predict_results.json /content/drive/MyDrive/T5_ANS_UNAW_SVAMP
# !cp eval_results.json /content/drive/MyDrive/T5_ANS_UNAW_SVAMP
# !cp training_args.bin /content/drive/MyDrive/T5_ANS_UNAW_SVAMP
# !cp trainer_state.json /content/drive/MyDrive/T5_ANS_UNAW_SVAMP
# !cp vocab.json /content/drive/MyDrive/T5_ANS_UNAW_SVAMP
# !cp special_tokens_map.json /content/drive/MyDrive/T5_ANS_UNAW_SVAMP
# !cp tokenizer_config.json /content/drive/MyDrive/T5_ANS_UNAW_SVAMP
# !cp pytorch_model.bin /content/drive/MyDrive/T5_ANS_UNAW_SVAMP
# !cp README.md /content/drive/MyDrive/T5_ANS_UNAW_SVAMP
# !cp generated_predictions.txt /content/drive/MyDrive/T5_ANS_UNAW_SVAMP
# !cp train_results.json /content/drive/MyDrive/T5_ANS_UNAW_SVAMP
# ...

# %%
# !cp -r /content/transformers/examples/pytorch/summarization/output-bart/checkpoint-2500 /content/drive/MyDrive/T5_ANS_UNAW_SVAMP
# !cp -r /content/transformers/examples/pytorch/summarization/output-bart/checkpoint-7500 /content/drive/MyDrive/T5_ANS_UNAW_SVAMP
# !cp -r /content/transformers/examples/pytorch/summarization/output-bart/checkpoint-10000 /content/drive/MyDrive/T5_ANS_UNAW_SVAMP
# !cp -r /content/transformers/examples/pytorch/summarization/output-bart/checkpoint-10500 /content/drive/MyDrive/T5_ANS_UNAW_SVAMP
# !cp -r /content/transformers/examples/pytorch/summarization/output-bart/checkpoint-15000 /content/drive/MyDrive/T5_ANS_UNAW_SVAMP

# !cp output-bart/tokenizer.json /content/drive/MyDrive/T5_ANS_UNAW_SVAMP
# !cp output-bart/generation_config.json /content/drive/MyDrive/T5_ANS_UNAW_SVAMP
# !cp output-bart/all_results.json /content/drive/MyDrive/T5_ANS_UNAW_SVAMP
# !cp output-bart/config.json /content/drive/MyDrive/T5_ANS_UNAW_SVAMP
# !cp output-bart/predict_results.json /content/drive/MyDrive/T5_ANS_UNAW_SVAMP
# !cp output-bart/eval_results.json /content/drive/MyDrive/T5_ANS_UNAW_SVAMP
# !cp output-bart/training_args.bin /content/drive/MyDrive/T5_ANS_UNAW_SVAMP
# !cp output-bart/trainer_state.json /content/drive/MyDrive/T5_ANS_UNAW_SVAMP
# !cp output-bart/vocab.json /content/drive/MyDrive/T5_ANS_UNAW_SVAMP
# !cp output-bart/special_tokens_map.json /content/drive/MyDrive/T5_ANS_UNAW_SVAMP
# !cp output-bart/tokenizer_config.json /content/drive/MyDrive/T5_ANS_UNAW_SVAMP
# !cp output-bart/pytorch_model.bin /content/drive/MyDrive/T5_ANS_UNAW_SVAMP
# !cp output-bart/README.md /content/drive/MyDrive/T5_ANS_UNAW_SVAMP
# !cp output-bart/generated_predictions.txt /content/drive/MyDrive/T5_ANS_UNAW_SVAMP
# !cp output-bart/train_results.json /content/drive/MyDrive/T5_ANS_UNAW_SVAMP
# !cp output-bart/merges.txt /content/drive/MyDrive/T5_ANS_UNAW_SVAMP

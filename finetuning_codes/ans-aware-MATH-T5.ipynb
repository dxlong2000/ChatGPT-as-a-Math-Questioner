# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/
# !git clone -q https://github.com/huggingface/transformers
# %cd transformers
# !pip install -q .
# Out:
# /content
# /content/transformers
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 80.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 224.5/224.5 kB 27.0 MB/s eta 0:00:00
# ...

# %%
# %cd /content/drive/MyDrive/AI for Education/MATH Dataset/Context_Aware_Answer_Aware_Finetune
# Out:
# /content/drive/.shortcut-targets-by-id/1EAqDcJ0Br8EpWp1jn5mdCzFlU0zynnoj/AI_Education/MATH Dataset/Context_Aware_Answer_Aware_Finetune

# %%
# !cp '/content/drive/MyDrive/AI for Education/MATH Dataset/Context_Aware_Answer_Aware_Finetune/train_and_val.csv' /content/transformers/examples/pytorch/summarization
# !cp '/content/drive/MyDrive/AI for Education/MATH Dataset/Context_Aware_Answer_Aware_Finetune/test.csv' /content/transformers/examples/pytorch/summarization

# %%
# %cd /content/transformers/examples/pytorch/summarization
# !pip install -r requirements.txt

# %% [markdown]
# ## <h1> 1. T5

# %%
# !python3 run_summarization.py \
    --model_name_or_path t5-base \
    --do_train \
    --do_eval \
    --do_predict \
    --train_file 'train_and_val.csv' \
    --validation_file 'test.csv' \
    --test_file 'test.csv' \
    --text_column text \
    --summary_column headlines \
    --source_prefix "generate a math question from context: " \
    --output_dir  'output-T5' \
    --logging_dir  'output-T5' \
    --per_device_train_batch_size=2 \
    --per_device_eval_batch_size=2 \
    --gradient_accumulation_steps=2 \
    --predict_with_generate=True \
    --learning_rate=0.00002 \
    --num_beams=5 \
    --max_steps=1000 \
    --save_steps=500 \
    --eval_steps=500 \
    --evaluation_strategy steps \
    --load_best_model \
    --overwrite_output_dir
# Out:
# Streaming output truncated to the last 5000 lines.
#   3% 69/2499 [01:03<47:18,  1.17s/it]
#   3% 70/2499 [01:04<43:05,  1.06s/it]
#   3% 71/2499 [01:06<57:34,  1.42s/it]
#   3% 72/2499 [01:07<55:00,  1.36s/it]
#   3% 73/2499 [01:08<46:45,  1.16s/it]
#   3% 74/2499 [01:09<42:26,  1.05s/it]
#   3% 75/2499 [01:10<38:26,  1.05it/s]
#   3% 76/2499 [01:11<42:45,  1.06s/it]
#   3% 77/2499 [01:12<45:33,  1.13s/it]
#   3% 78/2499 [01:13<47:01,  1.17s/it]
#   3% 79/2499 [01:14<44:18,  1.10s/it]
#   3% 80/2499 [01:15<40:46,  1.01s/it]
#   3% 81/2499 [01:16<40:22,  1.00s/it]
#   3% 82/2499 [01:19<1:02:25,  1.55s/it]
#   3% 83/2499 [01:20<51:13,  1.27s/it]
#   3% 84/2499 [01:20<45:13,  1.12s/it]
#   3% 85/2499 [01:21<39:02,  1.03it/s]
#   3% 86/2499 [01:22<33:21,  1.21it/s]
#   3% 87/2499 [01:22<29:22,  1.37it/s]
#   4% 88/2499 [01:23<32:42,  1.23it/s]
#   4% 89/2499 [01:26<53:56,  1.34s/it]
#   4% 90/2499 [01:26<45:06,  1.12s/it]
#   4% 91/2499 [01:27<38:33,  1.04it/s]
# ...

# %% [markdown]
# ## Resume training

# %%
# %cd /content/transformers/examples/pytorch/summarization
# !mkdir output-T5
# Out:
# /content/transformers/examples/pytorch/summarization

# %%
# !cp -r /content/drive/MyDrive/SVAMP_TEMP/checkpoint-10000 /content/transformers/examples/pytorch/summarization/output-T5/

# %%
# !rm -r /content/transformers/examples/pytorch/summarization/output-T5/checkpoint-2500

# %%
# !python3 run_summarization.py \
    --model_name_or_path t5-base \
    --do_train \
    --do_eval \
    --do_predict \
    --train_file 'train_and_val.csv' \
    --validation_file 'test.csv' \
    --test_file 'test.csv' \
    --text_column text \
    --summary_column headlines \
    --source_prefix "generate a math question from context: " \
    --output_dir  'output-T5' \
    --logging_dir  'output-T5' \
    --per_device_train_batch_size=2 \
    --per_device_eval_batch_size=2 \
    --gradient_accumulation_steps=2 \
    --predict_with_generate=True \
    --learning_rate=0.00002 \
    --num_beams=5 \
    --max_steps=10000 \
    --save_steps=500 \
    --eval_steps=500 \
    --evaluation_strategy steps \
    --load_best_model
# Out:
# 2023-05-05 06:51:31.855868: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 05/05/2023 06:51:35 - WARNING - __main__ - Process rank: 0, device: cuda:0, n_gpu: 1distributed training: True, 16-bits training: False
# 05/05/2023 06:51:35 - INFO - __main__ - Training/evaluation parameters Seq2SeqTrainingArguments(
# _n_gpu=1,
# adafactor=False,
# adam_beta1=0.9,
# adam_beta2=0.999,
# adam_epsilon=1e-08,
# auto_find_batch_size=False,
# bf16=False,
# bf16_full_eval=False,
# data_seed=None,
# dataloader_drop_last=False,
# dataloader_num_workers=0,
# dataloader_pin_memory=True,
# ddp_backend=None,
# ddp_bucket_cap_mb=None,
# ddp_find_unused_parameters=None,
# ddp_timeout=1800,
# debug=[],
# deepspeed=None,
# disable_tqdm=False,
# do_eval=True,
# do_predict=True,
# do_train=True,
# eval_accumulation_steps=None,
# eval_delay=0,
# eval_steps=500,
# evaluation_strategy=steps,
# fp16=False,
# fp16_backend=auto,
# fp16_full_eval=False,
# ...

# %%
# %cd /content/transformers/examples/pytorch/summarization/output-T5
# !cp all_results.json /content/drive/MyDrive/SVAMP_TEMP
# !cp README.md /content/drive/MyDrive/SVAMP_TEMP
# !cp eval_results.json /content/drive/MyDrive/SVAMP_TEMP
# !cp generated_predictions.txt /content/drive/MyDrive/SVAMP_TEMP
# !cp generation_config.json /content/drive/MyDrive/SVAMP_TEMP
# !cp config.json /content/drive/MyDrive/SVAMP_TEMP
# !cp predict_results.json /content/drive/MyDrive/SVAMP_TEMP
# !cp special_tokens_map.json /content/drive/MyDrive/SVAMP_TEMP
# !cp spiece.model /content/drive/MyDrive/SVAMP_TEMP
# !cp tokenizer.json /content/drive/MyDrive/SVAMP_TEMP
# !cp tokenizer_config.json /content/drive/MyDrive/SVAMP_TEMP
# !cp train_results.json /content/drive/MyDrive/SVAMP_TEMP
# !cp trainer_state.json /content/drive/MyDrive/SVAMP_TEMP
# !cp training_args.bin /content/drive/MyDrive/SVAMP_TEMP
# !cp pytorch_model.bin /content/drive/MyDrive/SVAMP_TEMP
# !cp 'events.out.tfevents.1682842493.4f58f4c95b04.1337.0' /content/drive/MyDrive/SVAMP_TEMP
# !cp 'events.out.tfevents.1682848562.4f58f4c95b04.1337.2' /content/drive/MyDrive/SVAMP_TEMP
# Out:
# /content/transformers/examples/pytorch/summarization/output-T5

# %%
with open("generated_predictions.txt", "r") as file:
    cnt = 0 
    for line in file:
        cnt += 1
    print(cnt)
# Out:
# 4998

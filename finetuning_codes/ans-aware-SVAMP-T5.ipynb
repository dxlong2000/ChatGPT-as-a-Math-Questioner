# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !rm -r /content/transformers

# %%
# %cd /content/
# !git clone https://github.com/huggingface/transformers
# %cd transformers
# !pip install .

# %%
# %cd /content/drive/MyDrive/NLP Research with Prof. Luu/AI for Education/SVAMP

# %%
# import pandas as pd
# import json
# with open('SVAMP.json', 'r') as file:
#     data = json.load(file) 

# df = pd.DataFrame(data)

# %%
# df["headlines"] = df["Question"]
# df["text"] = "Context: "+ df["Body"] + "\nAnswer" + df["Equation"].astype(str)

# %%
# from sklearn.model_selection import train_test_split
# import numpy as np

# # Split the data into training and test sets with a seed of 42
# train_data, test_data = train_test_split(df, test_size=0.2, random_state=42)
# train_data, valid_data = train_test_split(train_data, test_size=0.25, random_state=42)

# pd.DataFrame(train_data).to_csv("train.csv")
# pd.DataFrame(valid_data).to_csv("val.csv")
# pd.DataFrame(test_data).to_csv("test.csv")

# %% [markdown]
# <h1> 1. T5

# %%
# !cp "/content/drive/MyDrive/NLP Research with Prof. Luu/AI for Education/SVAMP/train_merge.csv" /content/transformers/examples/pytorch/summarization
# !cp "/content/drive/MyDrive/NLP Research with Prof. Luu/AI for Education/SVAMP/val.csv" /content/transformers/examples/pytorch/summarization
# !cp "/content/drive/MyDrive/NLP Research with Prof. Luu/AI for Education/SVAMP/test.csv" /content/transformers/examples/pytorch/summarization

# %%
# %cd /content/transformers/examples/pytorch/summarization
# !pip install -r requirements.txt
# Out:
#   Building wheel for rouge-score (setup.py) ... done
#   Created wheel for rouge-score: filename=rouge_score-0.1.2-py3-none-any.whl size=24954 sha256=273acd8214c38b7f27c18eaca2e6e30292347c86e9c25200eb5df4eef57ea0ad
#   Stored in directory: /root/.cache/pip/wheels/5f/dd/89/461065a73be61a532ff8599a28e9beef17985c9e9c31e541b4
# Successfully built rouge-score
# Installing collected packages: texttable, sentencepiece, brotli, xxhash, pyzstd, pyppmd, pycryptodomex, pybcj, multivolumefile, multidict, inflate64, frozenlist, dill, async-timeout, yarl, rouge-score, responses, py7zr, multiprocess, aiosignal, aiohttp, datasets, evaluate, accelerate
# Successfully installed accelerate-0.18.0 aiohttp-3.8.4 aiosignal-1.3.1 async-timeout-4.0.2 brotli-1.0.9 datasets-2.12.0 dill-0.3.6 evaluate-0.4.0 frozenlist-1.3.3 inflate64-0.3.1 multidict-6.0.4 multiprocess-0.70.14 multivolumefile-0.2.3 py7zr-0.20.5 pybcj-1.0.1 pycryptodomex-3.17 pyppmd-1.0.0 pyzstd-0.15.7 responses-0.18.0 rouge-score-0.1.2 sentencepiece-0.1.98 texttable-1.6.7 xxhash-3.2.0 yarl-1.9.2

# %%
# start training
# !python3 run_summarization.py \
    --model_name_or_path t5-base \
    --do_train \
    --do_eval \
    --do_predict \
    --train_file 'train_merge.csv' \
    --validation_file 'test.csv' \
    --test_file 'test.csv' \
    --text_column text \
    --summary_column headlines \
    --source_prefix "generate a math question from context: " \
    --output_dir  'output-T5' \
    --logging_dir  'output-T5' \
    --per_device_train_batch_size=2 \
    --per_device_eval_batch_size=2 \
    --gradient_accumulation_steps=2 \
    --predict_with_generate=True \
    --learning_rate=0.00001 \
    --num_beams=5 \
    --max_steps=15000 \
    --save_steps=500 \
    --eval_steps=500 \
    --evaluation_strategy steps \
    --load_best_model \
    --overwrite_output_dir
# Out:
# 2023-04-30 08:14:33.783770: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 04/30/2023 08:14:37 - WARNING - __main__ - Process rank: 0, device: cuda:0, n_gpu: 1distributed training: True, 16-bits training: False
# 04/30/2023 08:14:37 - INFO - __main__ - Training/evaluation parameters Seq2SeqTrainingArguments(
# _n_gpu=1,
# adafactor=False,
# adam_beta1=0.9,
# adam_beta2=0.999,
# adam_epsilon=1e-08,
# auto_find_batch_size=False,
# bf16=False,
# bf16_full_eval=False,
# data_seed=None,
# dataloader_drop_last=False,
# dataloader_num_workers=0,
# dataloader_pin_memory=True,
# ddp_bucket_cap_mb=None,
# ddp_find_unused_parameters=None,
# ddp_timeout=1800,
# debug=[],
# deepspeed=None,
# disable_tqdm=False,
# do_eval=True,
# do_predict=True,
# do_train=True,
# eval_accumulation_steps=None,
# eval_delay=0,
# eval_steps=500,
# evaluation_strategy=steps,
# fp16=False,
# fp16_backend=auto,
# fp16_full_eval=False,
# fp16_opt_level=O1,
# fsdp=[],
# fsdp_config={'fsdp_min_num_params': 0, 'xla': False, 'xla_fsdp_grad_ckpt': False},
# fsdp_min_num_params=0,
# fsdp_transformer_layer_cls_to_wrap=None,
# full_determinism=False,
# generation_config=None,
# generation_max_length=None,
# generation_num_beams=None,
# gradient_accumulation_steps=2,
# gradient_checkpointing=False,
# greater_is_better=False,
# group_by_length=False,
# half_precision_backend=auto,
# hub_model_id=None,
# hub_private_repo=False,
# hub_strategy=every_save,
# hub_token=<HUB_TOKEN>,
# ignore_data_skip=False,
# include_inputs_for_metrics=False,
# jit_mode_eval=False,
# label_names=None,
# label_smoothing_factor=0.0,
# learning_rate=1e-05,
# length_column_name=length,
# load_best_model_at_end=True,
# local_rank=0,
# log_level=passive,
# log_level_replica=warning,
# log_on_each_node=True,
# logging_dir=output-T5,
# logging_first_step=False,
# logging_nan_inf_filter=True,
# logging_steps=500,
# logging_strategy=steps,
# lr_scheduler_type=linear,
# max_grad_norm=1.0,
# max_steps=15000,
# metric_for_best_model=loss,
# mp_parameters=,
# no_cuda=False,
# num_train_epochs=3.0,
# optim=adamw_hf,
# optim_args=None,
# output_dir=output-T5,
# overwrite_output_dir=True,
# past_index=-1,
# per_device_eval_batch_size=2,
# per_device_train_batch_size=2,
# predict_with_generate=True,
# prediction_loss_only=False,
# push_to_hub=False,
# push_to_hub_model_id=None,
# push_to_hub_organization=None,
# push_to_hub_token=<PUSH_TO_HUB_TOKEN>,
# ray_scope=last,
# remove_unused_columns=True,
# report_to=['tensorboard'],
# resume_from_checkpoint=None,
# run_name=output-T5,
# save_on_each_node=False,
# save_safetensors=False,
# save_steps=500,
# save_strategy=steps,
# save_total_limit=None,
# seed=42,
# sharded_ddp=[],
# skip_memory_metrics=True,
# sortish_sampler=False,
# tf32=None,
# torch_compile=False,
# torch_compile_backend=None,
# torch_compile_mode=None,
# torchdynamo=None,
# tpu_metrics_debug=False,
# tpu_num_cores=None,
# use_ipex=False,
# use_legacy_prediction_loop=False,
# use_mps_device=False,
# warmup_ratio=0.0,
# warmup_steps=0,
# weight_decay=0.0,
# xpu_backend=None,
# )
# 04/30/2023 08:14:38 - INFO - datasets.builder - Using custom data configuration default-7e620b36ce2a1402
# 04/30/2023 08:14:38 - INFO - datasets.info - Loading Dataset Infos from /usr/local/lib/python3.10/dist-packages/datasets/packaged_modules/csv
# 04/30/2023 08:14:38 - INFO - datasets.builder - Generating dataset csv (/root/.cache/huggingface/datasets/csv/default-7e620b36ce2a1402/0.0.0/6954658bab30a358235fa864b05cf819af0e179325c740e4bc853bcc7ec513e1)
# Downloading and preparing dataset csv/default to /root/.cache/huggingface/datasets/csv/default-7e620b36ce2a1402/0.0.0/6954658bab30a358235fa864b05cf819af0e179325c740e4bc853bcc7ec513e1...
# Downloading data files: 100% 3/3 [00:00<00:00, 11164.96it/s]
# 04/30/2023 08:14:38 - INFO - datasets.download.download_manager - Downloading took 0.0 min
# 04/30/2023 08:14:38 - INFO - datasets.download.download_manager - Checksum Computation took 0.0 min
# Extracting data files: 100% 3/3 [00:00<00:00, 1859.45it/s]
# 04/30/2023 08:14:38 - INFO - datasets.builder - Generating train split
# 04/30/2023 08:14:38 - INFO - datasets.builder - Generating validation split
# 04/30/2023 08:14:38 - INFO - datasets.builder - Generating test split
# 04/30/2023 08:14:38 - INFO - datasets.utils.info_utils - Unable to verify splits sizes.
# Dataset csv downloaded and prepared to /root/.cache/huggingface/datasets/csv/default-7e620b36ce2a1402/0.0.0/6954658bab30a358235fa864b05cf819af0e179325c740e4bc853bcc7ec513e1. Subsequent calls will reuse this data.
# 100% 3/3 [00:00<00:00, 765.43it/s]
# Downloading (…)lve/main/config.json: 100% 1.21k/1.21k [00:00<00:00, 9.54MB/s]
# [INFO|configuration_utils.py:669] 2023-04-30 08:14:38,358 >> loading configuration file config.json from cache at /root/.cache/huggingface/hub/models--t5-base/snapshots/fe6d9bf207cd3337512ca838a8b453f87a9178ef/config.json
# [INFO|configuration_utils.py:725] 2023-04-30 08:14:38,361 >> Model config T5Config {
#   "_name_or_path": "t5-base",
#   "architectures": [
#     "T5ForConditionalGeneration"
#   ],
#   "d_ff": 3072,
#   "d_kv": 64,
#   "d_model": 768,
#   "decoder_start_token_id": 0,
#   "dense_act_fn": "relu",
#   "dropout_rate": 0.1,
#   "eos_token_id": 1,
#   "feed_forward_proj": "relu",
#   "initializer_factor": 1.0,
#   "is_encoder_decoder": true,
#   "is_gated_act": false,
#   "layer_norm_epsilon": 1e-06,
#   "model_type": "t5",
#   "n_positions": 512,
#   "num_decoder_layers": 12,
#   "num_heads": 12,
#   "num_layers": 12,
#   "output_past": true,
#   "pad_token_id": 0,
#   "relative_attention_max_distance": 128,
#   "relative_attention_num_buckets": 32,
#   "task_specific_params": {
#     "summarization": {
#       "early_stopping": true,
#       "length_penalty": 2.0,
#       "max_length": 200,
#       "min_length": 30,
#       "no_repeat_ngram_size": 3,
#       "num_beams": 4,
#       "prefix": "summarize: "
#     },
#     "translation_en_to_de": {
#       "early_stopping": true,
#       "max_length": 300,
#       "num_beams": 4,
#       "prefix": "translate English to German: "
#     },
#     "translation_en_to_fr": {
#       "early_stopping": true,
#       "max_length": 300,
#       "num_beams": 4,
#       "prefix": "translate English to French: "
#     },
#     "translation_en_to_ro": {
#       "early_stopping": true,
#       "max_length": 300,
#       "num_beams": 4,
#       "prefix": "translate English to Romanian: "
#     }
#   },
#   "transformers_version": "4.29.0.dev0",
#   "use_cache": true,
#   "vocab_size": 32128
# }
#
# [INFO|tokenization_auto.py:502] 2023-04-30 08:14:38,406 >> Could not locate the tokenizer configuration file, will try to use the model config instead.
# [INFO|configuration_utils.py:669] 2023-04-30 08:14:38,451 >> loading configuration file config.json from cache at /root/.cache/huggingface/hub/models--t5-base/snapshots/fe6d9bf207cd3337512ca838a8b453f87a9178ef/config.json
# [INFO|configuration_utils.py:725] 2023-04-30 08:14:38,452 >> Model config T5Config {
#   "_name_or_path": "t5-base",
#   "architectures": [
#     "T5ForConditionalGeneration"
#   ],
#   "d_ff": 3072,
#   "d_kv": 64,
#   "d_model": 768,
#   "decoder_start_token_id": 0,
#   "dense_act_fn": "relu",
#   "dropout_rate": 0.1,
#   "eos_token_id": 1,
#   "feed_forward_proj": "relu",
#   "initializer_factor": 1.0,
#   "is_encoder_decoder": true,
#   "is_gated_act": false,
#   "layer_norm_epsilon": 1e-06,
#   "model_type": "t5",
#   "n_positions": 512,
#   "num_decoder_layers": 12,
#   "num_heads": 12,
#   "num_layers": 12,
#   "output_past": true,
#   "pad_token_id": 0,
#   "relative_attention_max_distance": 128,
#   "relative_attention_num_buckets": 32,
#   "task_specific_params": {
#     "summarization": {
#       "early_stopping": true,
#       "length_penalty": 2.0,
#       "max_length": 200,
#       "min_length": 30,
#       "no_repeat_ngram_size": 3,
#       "num_beams": 4,
#       "prefix": "summarize: "
#     },
#     "translation_en_to_de": {
#       "early_stopping": true,
#       "max_length": 300,
#       "num_beams": 4,
#       "prefix": "translate English to German: "
#     },
#     "translation_en_to_fr": {
#       "early_stopping": true,
#       "max_length": 300,
#       "num_beams": 4,
#       "prefix": "translate English to French: "
#     },
#     "translation_en_to_ro": {
#       "early_stopping": true,
#       "max_length": 300,
#       "num_beams": 4,
#       "prefix": "translate English to Romanian: "
#     }
#   },
#   "transformers_version": "4.29.0.dev0",
#   "use_cache": true,
#   "vocab_size": 32128
# }
#
# Downloading (…)ve/main/spiece.model: 100% 792k/792k [00:00<00:00, 6.22MB/s]
# Downloading (…)/main/tokenizer.json: 100% 1.39M/1.39M [00:00<00:00, 11.8MB/s]
# [INFO|tokenization_utils_base.py:1810] 2023-04-30 08:14:39,120 >> loading file spiece.model from cache at /root/.cache/huggingface/hub/models--t5-base/snapshots/fe6d9bf207cd3337512ca838a8b453f87a9178ef/spiece.model
# [INFO|tokenization_utils_base.py:1810] 2023-04-30 08:14:39,120 >> loading file tokenizer.json from cache at /root/.cache/huggingface/hub/models--t5-base/snapshots/fe6d9bf207cd3337512ca838a8b453f87a9178ef/tokenizer.json
# [INFO|tokenization_utils_base.py:1810] 2023-04-30 08:14:39,120 >> loading file added_tokens.json from cache at None
# [INFO|tokenization_utils_base.py:1810] 2023-04-30 08:14:39,120 >> loading file special_tokens_map.json from cache at None
# [INFO|tokenization_utils_base.py:1810] 2023-04-30 08:14:39,120 >> loading file tokenizer_config.json from cache at None
# [INFO|configuration_utils.py:669] 2023-04-30 08:14:39,120 >> loading configuration file config.json from cache at /root/.cache/huggingface/hub/models--t5-base/snapshots/fe6d9bf207cd3337512ca838a8b453f87a9178ef/config.json
# [INFO|configuration_utils.py:725] 2023-04-30 08:14:39,121 >> Model config T5Config {
#   "_name_or_path": "t5-base",
#   "architectures": [
#     "T5ForConditionalGeneration"
#   ],
#   "d_ff": 3072,
#   "d_kv": 64,
#   "d_model": 768,
#   "decoder_start_token_id": 0,
#   "dense_act_fn": "relu",
#   "dropout_rate": 0.1,
#   "eos_token_id": 1,
#   "feed_forward_proj": "relu",
#   "initializer_factor": 1.0,
#   "is_encoder_decoder": true,
#   "is_gated_act": false,
#   "layer_norm_epsilon": 1e-06,
#   "model_type": "t5",
#   "n_positions": 512,
#   "num_decoder_layers": 12,
#   "num_heads": 12,
#   "num_layers": 12,
#   "output_past": true,
#   "pad_token_id": 0,
#   "relative_attention_max_distance": 128,
#   "relative_attention_num_buckets": 32,
#   "task_specific_params": {
#     "summarization": {
#       "early_stopping": true,
#       "length_penalty": 2.0,
#       "max_length": 200,
#       "min_length": 30,
#       "no_repeat_ngram_size": 3,
#       "num_beams": 4,
#       "prefix": "summarize: "
#     },
#     "translation_en_to_de": {
#       "early_stopping": true,
#       "max_length": 300,
#       "num_beams": 4,
#       "prefix": "translate English to German: "
#     },
#     "translation_en_to_fr": {
#       "early_stopping": true,
#       "max_length": 300,
#       "num_beams": 4,
#       "prefix": "translate English to French: "
#     },
#     "translation_en_to_ro": {
#       "early_stopping": true,
#       "max_length": 300,
#       "num_beams": 4,
#       "prefix": "translate English to Romanian: "
#     }
#   },
#   "transformers_version": "4.29.0.dev0",
#   "use_cache": true,
#   "vocab_size": 32128
# }
#
# /usr/local/lib/python3.10/dist-packages/transformers/models/t5/tokenization_t5_fast.py:155: FutureWarning: This tokenizer was incorrectly instantiated with a model max length of 512 which will be corrected in Transformers v5.
# For now, this behavior is kept to avoid breaking backwards compatibility when padding/encoding with `truncation is True`.
# - Be aware that you SHOULD NOT rely on t5-base automatically truncating your input to 512 when padding/encoding.
# - If you want to encode/pad to sequences longer than 512 you can either instantiate this tokenizer with `model_max_length` or pass `max_length` when encoding/padding.
# - To avoid this warning, please instantiate this tokenizer with `model_max_length` set to your preferred value.
#   warnings.warn(
# Downloading pytorch_model.bin: 100% 892M/892M [00:04<00:00, 203MB/s]
# [INFO|modeling_utils.py:2542] 2023-04-30 08:14:43,720 >> loading weights file pytorch_model.bin from cache at /root/.cache/huggingface/hub/models--t5-base/snapshots/fe6d9bf207cd3337512ca838a8b453f87a9178ef/pytorch_model.bin
# [INFO|configuration_utils.py:577] 2023-04-30 08:14:44,250 >> Generate config GenerationConfig {
#   "_from_model_config": true,
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.29.0.dev0"
# }
#
# [INFO|modeling_utils.py:3211] 2023-04-30 08:14:47,458 >> All model checkpoint weights were used when initializing T5ForConditionalGeneration.
#
# [INFO|modeling_utils.py:3219] 2023-04-30 08:14:47,458 >> All the weights of T5ForConditionalGeneration were initialized from the model checkpoint at t5-base.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use T5ForConditionalGeneration for predictions without further training.
# Downloading (…)neration_config.json: 100% 147/147 [00:00<00:00, 1.01MB/s]
# [INFO|configuration_utils.py:539] 2023-04-30 08:14:47,563 >> loading configuration file generation_config.json from cache at /root/.cache/huggingface/hub/models--t5-base/snapshots/fe6d9bf207cd3337512ca838a8b453f87a9178ef/generation_config.json
# [INFO|configuration_utils.py:577] 2023-04-30 08:14:47,564 >> Generate config GenerationConfig {
#   "_from_model_config": true,
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.29.0.dev0"
# }
#
# Running tokenizer on train dataset:   0% 0/800 [00:00<?, ? examples/s]04/30/2023 08:14:47 - INFO - datasets.arrow_dataset - Caching processed dataset at /root/.cache/huggingface/datasets/csv/default-7e620b36ce2a1402/0.0.0/6954658bab30a358235fa864b05cf819af0e179325c740e4bc853bcc7ec513e1/cache-9631af5ccd5c09a9.arrow
# Running tokenizer on validation dataset:   0% 0/200 [00:00<?, ? examples/s]04/30/2023 08:14:47 - INFO - datasets.arrow_dataset - Caching processed dataset at /root/.cache/huggingface/datasets/csv/default-7e620b36ce2a1402/0.0.0/6954658bab30a358235fa864b05cf819af0e179325c740e4bc853bcc7ec513e1/cache-ba65dbd45ffd1b81.arrow
# Running tokenizer on prediction dataset:   0% 0/200 [00:00<?, ? examples/s]04/30/2023 08:14:48 - INFO - datasets.arrow_dataset - Caching processed dataset at /root/.cache/huggingface/datasets/csv/default-7e620b36ce2a1402/0.0.0/6954658bab30a358235fa864b05cf819af0e179325c740e4bc853bcc7ec513e1/cache-330bc4559c51e634.arrow
# Downloading builder script: 100% 6.27k/6.27k [00:00<00:00, 5.19MB/s]
# [INFO|trainer.py:563] 2023-04-30 08:14:53,274 >> max_steps is given, it will override any value given in num_train_epochs
# /usr/local/lib/python3.10/dist-packages/transformers/optimization.py:407: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   warnings.warn(
# [INFO|trainer.py:1769] 2023-04-30 08:14:53,290 >> ***** Running training *****
# [INFO|trainer.py:1770] 2023-04-30 08:14:53,291 >>   Num examples = 800
# [INFO|trainer.py:1771] 2023-04-30 08:14:53,291 >>   Num Epochs = 75
# [INFO|trainer.py:1772] 2023-04-30 08:14:53,291 >>   Instantaneous batch size per device = 2
# [INFO|trainer.py:1773] 2023-04-30 08:14:53,291 >>   Total train batch size (w. parallel, distributed & accumulation) = 4
# [INFO|trainer.py:1774] 2023-04-30 08:14:53,291 >>   Gradient Accumulation steps = 2
# [INFO|trainer.py:1775] 2023-04-30 08:14:53,291 >>   Total optimization steps = 15,000
# [INFO|trainer.py:1776] 2023-04-30 08:14:53,293 >>   Number of trainable parameters = 222,903,552
#   0% 0/15000 [00:00<?, ?it/s][WARNING|logging.py:280] 2023-04-30 08:14:53,318 >> You're using a T5TokenizerFast tokenizer. Please note that with a fast tokenizer, using the `__call__` method is faster than using a method to encode the text followed by a call to the `pad` method to get a padded encoding.
# {'loss': 1.2715, 'learning_rate': 9.666666666666667e-06, 'epoch': 2.5}
#   3% 500/15000 [02:24<59:34,  4.06it/s][INFO|trainer.py:3136] 2023-04-30 08:17:17,658 >> ***** Running Evaluation *****
# [INFO|trainer.py:3138] 2023-04-30 08:17:17,658 >>   Num examples = 200
# [INFO|trainer.py:3141] 2023-04-30 08:17:17,658 >>   Batch size = 2
# [INFO|configuration_utils.py:577] 2023-04-30 08:17:17,661 >> Generate config GenerationConfig {
#   "_from_model_config": true,
#   "decoder_start_token_id": 0,
#   "eos_token_id": 1,
#   "pad_token_id": 0,
#   "transformers_version": "4.29.0.dev0"
# }
#
#
#   0% 0/100 [00:00<?, ?it/s]
#   2% 2/100 [00:00<00
#  62% 62/100 [00:29<00:17,  2.13it/s]
#  63% 63/100 [00:30<00:16,  2.30it/s]
#  64% 64/100 [00:30<00:14,  2.53it/s]
#  65% 65/100 [00:30<00:13,  2.62it/s]
#  66% 66/100 [00:31<00:12,  2.69it/s]
#  67% 67/100 [00:31<00:13,  2.54it/s]
#  68% 68/100 [00:31<00:12,  2.66it/s]
#  69% 69/100 [00:32<00:12,  2.58it/s]
#  70% 70/100 [00:32<00:12,  2.41it/s]
#  71% 71/100 [00:33<00:12,  2.30it/s]
#  72% 72/100 [00:33<00:11,  2.40it/s]
#  73% 73/100 [00:34<00:11,  2.39it/s]
#  74% 74/100 [00:34<00:10,  2.45it/s]
#  75% 75/100 [00:34<00:09,  2.65it/s]
#  76% 76/100 [00:35<00:08,  2.71it/s]
#  77% 77/100 [00:35<00:08,  2.71it/s]
#  78% 78/100 [00:35<00:07,  2.79it/s]
#  79% 79/100 [00:36<00:07,  2.80it/s]
#  80% 80/100 [00:36<00:06,  2.99it/s]
#  81% 81/100 [00:36<00:06,  2.93it/s]
#  82% 82/100 [00:37<00:06,  2.88it/s]
#  83% 83/100 [00:37<00:06,  2.64it/s]
#  84% 84/100 [00:38<00:06,  2.31it/s]
#  85% 85/100 [00:38<00:06,  2.35it/s]
#  86% 86/100 [00:39<00:06,  2.20it/s]
#  87% 87/100 [00:39<00:06,  2.06it/s]
#  88% 88/100 [00:40<00:05,  2.06it/s]
#  89% 89/100 [00:40<00:05,  2.10it/s]
#  90% 90/100 [00:41<00:05,  1.93it/s]
#  91% 91/100 [00:41<00:05,  1.76it/s]
#  92% 92/100 [00:42<00:04,  1.79it/s]
#  93% 93/100 [00:43<00:04,  1.62it/s]
#  94% 94/100 [00:43<00:03,  1.64it/s]
#  95% 95/100 [00:44<00:03,  1.59it/s]
#  96% 96/100 [00:44<00:02,  1.65it/s]
#  97% 97/100 [00:45<00:01,  1.51it/s]
#  98% 98/100 [00:46<00:01,  1.62it/s]
#  99% 99/100 [00:46<00:00,  1.75it/s]
#
# {'eval_loss': 0.8760409355163574, 'eval_rouge1': 64.2309, 'eval_rouge2': 44.0834, 'eval_rougeL': 62.0874, 'eval_rougeLsum': 62.0941, 'eval_gen_len': 12.565, 'eval_runtime': 48.0213, 'eval_samples_per_second': 4.165, 'eval_steps_per_second': 2.082, 'epoch': 2.5}
#   3% 500/15000 [03:12<59:34,  4.06it/s]
# 100% 100/100 [00:47<00:00,  1.84it/s]
#                                      [INFO|trainer.py:2875] 2023-04-30 08:18:05,681 >> Saving model checkpoint to output-T5/checkpoint-500
# [INFO|configuration_utils.py:458] 2023-04-30 08:18:05,682 >> Configuration saved in output-T5/checkpoint-500/config.json
# [INFO|configuration_utils.py:364] 2023-04-30 08:18:05,682 >> Configuration saved in output-T5/checkpoint-500/generation_config.json
# [INFO|modeling_utils.py:1855] 2023-04-30 08:18:08,821 >> Model weights saved in output-T5/checkpoint-500/pytorch_model.bin
# [INFO|tokenization_utils_base.py:2181] 2023-04-30 08:18:08,822 >> tokenizer config file saved in output-T5/checkpoint-500/tokenizer_config.json
# [INFO|tokenization_utils_base.py:2188] 2023
# 100% 100/100 [00:45<00:00,  2.35it/s]
#                                      [INFO|trainer.py:2875] 2023-04-30 08:21:25,879 >> Saving model checkpoint to output-T5/checkpoint-1000
# [INFO|configuration_utils.py:458] 2023-04-30 08:21:25,881 >> Configuration saved in output-T5/checkpoint-1000/config.json
# [INFO|configuration_utils.py:364] 2023-04-30 08:21:25,881 >> Configuration saved in output-T5/checkpoint-1000/generation_config.json
# [INFO|modeling_utils.py:1855] 2023-04-30 08:21:29,027 >> Model weights saved in output-T5/checkpoint-1000/pytorch_model.bin
# [INFO|tokenization_utils_base.py:2181] 2023-04-30 08:21:29,028 >> tokenizer config file saved in output-T5/checkpoint-1000/tokenizer_config.json
# [INFO|tokenization_utils_base.py:2188] 2023-04-30 08:21:29,029 >> Special tokens file saved in output-T5/checkpoint-1000/special_tokens_map.json
# [INFO|tokenization_t5_fast.py:186] 2023-04-30 08:21:29,168 >> Copy vocab file to output-T5/checkpoint-1000/spiece.model
# {'loss': 0.6812, 'learning_rate': 9e-06, 'epoch': 7.5}
#  10% 1500/15000 [09:05<55:36,  4.05it/s][INFO|trainer.py:3136] 2023-04-30 08:23:58,936 >> ***** Running Evaluation *****
# [INFO|trainer.py:3138] 2023-04-30 08:23:58,936 >>   Num examples = 200
# [INFO|trainer.py:3141] 2023-04-30 08:23:58,936 >>   Batch size = 2
#
#   0% 0/100 [00:00<?, ?it/s]
#   2% 2/100 [00:00<00:14,  6.54it/s]
#   3% 3/100 [00:00<00:26,  3.63it/s]
#   4% 4/100 [00:01<00:33,  2.84it/s]
#   5% 5/100 [00:01<00:32,  2.97it/s]
#   6% 6/100 [00:01<00:34,  2.72it/s]
#   7% 7/100 [00:02<00:32,  2.82it/s]
#   8% 8/100 [00:02<00:35,  2.60it/s]
#   9% 9/100 [00:03<00:37,  2.40it/s]
#  10% 10/100 [00:03<00:39,  2.29it/s]
#  11% 11/100 [00:04<00:40,  2.19it/s]
#  12% 12/100 [00:04<00:37,  2.32it/s]
#  13% 13/100 [00:05<00:40,  2.15it/s]
#  14% 14/100 [00:05<00:42,  2.02it/s]
#  15% 15/100 [00:06<00:41,  2.03it/s]
#  16% 16/100 [00:06<00:44,  1.89it/s]
#  17% 17/100 [00:07<00:47,  1.75it/s]
#  18% 18/100 [00:08<00:51,  1.59it/s]
#  19% 19/100 [00:08<00:50,  1.59it/s]
#  20% 20/100 [00:09<00:50,  1.59it/s]
#  21% 21/100 [00:10<00:48,  1.65it/s]
#  22% 22/100 [00:10<00:47,  1.63it/s]
#  23% 23/100 [00:11<00:47,  1.63it/s]
#  24% 24/100 [00:11<00:43,  1.74it/s]
#  25% 25/100 [00:12<00:40,  1.84it/s]
#  26% 26/100 [00:12<00:39,  1.88it/s]
#  27% 27/100 [00:13<00:34,  2.12it/s]
#  28% 28/100 [00:13<00:32,  2.19it/s]
#  29% 29/100 [00:13<00:29,  2.38it/s]
#  30% 30/100 [00:14<00:29,  2.38it/s]
#  31% 31/100 [00:14<00:27,  2.51it/s]
#  32% 32/100 [00:15<00:27,  2.51it/s]
#  33% 33/100 [00:15<00:25,  2.58it/s]
#  34% 34/100 [00:15<00:26,  2.45it/s]
#  35% 35/100 [00:16<00:25,  2.59it/s]
#  36% 36/100 [00:16<00:27,  2.33it/s]
#  37% 37/100 [00:17<00:27,  2.27it/s]
#  38% 38/100 [00:17<00:26,  2.38it/s]
#  96% 96/100 [00:43<00:02,  1.86it/s]
#  97% 97/100 [00:44<00:01,  1.67it/s]
#  98% 98/100 [00:44<00:01,  1.68it/s]
#  99% 99/100 [00:45<00:00,  1.68it/s]
#
# {'eval_loss': 0.6768745183944702, 'eval_rouge1': 69.5167, 'eval_rouge2': 51.1115, 'eval_rougeL': 67.0733, 'eval_rougeLsum': 67.1833, 'eval_gen_len': 13.44, 'eval_runtime': 47.2998, 'eval_samples_per_second': 4.228, 'eval_steps_per_second': 2.114, 'epoch': 7.5}
#  10% 1500/15000 [09:52<55:36,  4.05it/s]
# 100% 100/100 [00:46<00:00,  1.52it/s]
#                                      [INFO|trainer.py:2875] 2023-04-30 08:24:46,238 >> Saving model checkpoint to output-T5/checkpoint-1500
# [INFO|configuration_utils.py:458] 2023-04-30 08:24:46,239 >> Configuration saved in output-T5/checkpoint-1500/config.json
# [INFO|configuration_utils.py:364] 2023-04-30 08:24:46,240 >> Configuration saved in output-T5/checkpoint-1500/generation_config.json
# [INFO|modeling_utils.py:1855] 2023-04-30 08:24:49,357 >> Model weights saved in output-T5/checkpoint-1500/pytorch_model.bin
# [INFO|tokenization_utils_base.py:2181] 2023-04-30 08:24:49,357 >> tokenizer config file saved in output-T5/checkpoint-1500/tokenizer_config.json
# [INFO|tokenization_utils_base.py:2188] 2023-04-30 08:24:49,358 >> Special tokens file saved in output-T5/checkpoint-1500/special_tokens_map.json
# [INFO|tokenization_t5_fast.py:186] 2023-04-30 08:24:49,400 >> Copy vocab file to output-T5/checkpoint-1500/spiece.model
# {'loss': 0.5816, 'learning_rate': 8.666666666666668e-06, 'epoch': 10.0}
#  13% 2000/15000 [12:26<1:11:23,  3.04it/s][INFO|trainer.py:3136] 2023-04-30 08:27:19,502 >> ***** Running Evaluation *****
# [INFO|trainer.py:3138] 2023-04-30 08:27:19,502 >>   Num examples = 200
# [INFO|trainer.py:3141] 2023-04-30 08:27:19,503 >>   Batch size = 2
#
#   0% 0/100 [00:00<?, ?it/s]
#   2% 2/100 [00:00<00:23,  4.11it/s]
#   3% 3/100 [00:01<00:37,  2.61it/s]
#   4% 4/100 [00:01<00:44,  2.17it/s]
#   5% 5/100 [00:02<00:44,  2.15it/s]
#   6% 6/100 [00:02<00:50,  1.86it/s]
#   7% 7/100 [00:03<00:49,  1.87it/s]
#   8% 8/100 [00:03<00:50,  1.82it/s]
#   9% 9/100 [00:04<00:44,  2.04it/s]
#  10% 10/100 [00:04<00:40,  2.22it/s]
#  11% 11/100 [00:05<00:38,  2.29it/s]
#  12% 12/100 [00:05<00:33,  2.60it/s]
#  13% 13/100 [00:05<00:35,  2.48it/s]
#  14% 14/100 [00:06<00:34,  2.46it/s]
#  15% 15/100 [00:06<00:34,  2.45it/s]
#  16% 16/100 [00:06<00:33,  2.51it/s]
#  17% 17/100 [00:07<00:32,  2.56it/s]
#  18% 18/100 [00:07<00:34,  2.40it/s]
#  19% 19/100 [00:08<00:32,  2.48it/s]
#  20% 20/100 [00:08<00:31,  2.50it/s]
#  21% 21/100 [00:08<00:30,  2.62it/s]
#  22% 22/100 [00:09<00:28,  2.77it/s]
#  23% 23/100 [00:09<00:28,  2.73it/s]
#  24% 24/100 [00:09<00:27,  2.74it/s]
#  25% 25/100 [00:10<00:29,  2.53it/s]
#  26% 26/100 [00:10<00:31,  2.35it/s]
#  85% 85/100 [00:37<00:09,  1.65it/s]
#  86% 86/100 [00:38<00:08,  1.61it/s]
#  87% 87/100 [00:38<00:07,  1.64it/s]
#  88% 88/100 [00:39<00:07,  1.63it/s]
#  89% 89/100 [00:40<00:06,  1.66it/s]
#  90% 90/100 [00:40<00:06,  1.61it/s]
#  91% 91/100 [00:41<00:05,  1.75it/s]
#  92% 92/100 [00:41<00:04,  1.97it/s]
#  93% 93/100 [00:42<00:03,  2.07it/s]
#  94% 94/100 [00:42<00:02,  2.29it/s]
#  95% 95/100 [00:42<00:02,  2.47it/s]
#  96% 96/100 [00:43<00:01,  2.58it/s]
#  97% 97/100 [00:43<00:01,  2.56it/s]
#  98% 98/100 [00:43<00:00,  2.65it/s]
#  99% 99/100 [00:44<00:00,  2.68it/s]
#
# {'eval_loss': 0.6358804106712341, 'eval_rouge1': 71.5458, 'eval_rouge2': 53.99, 'eval_rougeL': 68.8878, 'eval_rougeLsum': 68.9234, 'eval_gen_len': 12.935, 'eval_runtime': 45.6114, 'eval_samples_per_second': 4.385, 'eval_steps_per_second': 2.192, 'epoch': 10.0}
#  13% 2000/15000 [13:11<1:11:23,  3.04it/s]
# 100% 100/100 [00:45<00:00,  2.43it/s]
#                                      [INFO|trainer.py:2875] 2023-04-30 08:28:05,116 >> Saving model checkpoint to output-T5/checkpoint-2000
# [INFO|configuration_utils.py:458] 2023-04-30 08:28:05,117 >> Configuration saved in output-T5/checkpoint-2000/config.json
# [INFO|configuration_utils.py:364] 2023-04-30 08:28:05,117 >> Configuration saved in output-T5/checkpoint-2000/generation_config.json
# [INFO|modeling_utils.py:1855] 2023-04-30 08:28:08,175 >> Model weights saved in output-T5/checkpoint-2000/pytorch_model.bin
# [INFO|tokenization_utils_base.py:2181] 2023-04-30 08:28:08,176 >> tokenizer config file saved in output-T5/checkpoint-2000/tokenizer_config.json
# [INFO|tokenization_utils_base.py:2188] 2023-04-30 08:28:08,176 >> Special tokens file saved in output-T5/checkpoint-2000/special_tokens_map.json
# [INFO|tokenization_t5_fast.py:186] 2023-04-30 08:28:08,220 >> Copy vocab file to output-T5/checkpoint-2000/spiece.model
# {'loss': 0.5072, 'learning_rate': 8.333333333333334e-06, 'epoch': 12.5}
#  17% 2500/15000 [15:46<50:43,  4.11it/s][INFO|trainer.py:3136] 2023-04-30 08:30:39,436 >> ***** Running Evaluation *****
# [INFO|trainer.py:3138] 2023-04-30 08:30:39,436 >>   Num examples = 200
# [INFO|trainer.py:3141] 2023-04-30 08:30:39,436 >>   Batch size = 2
#
#   0% 0/100 [00:00<?, ?it/s]
#   2% 2/100 [00:00<00:15,  6.38it/s]
#   3% 3/100 [00:00<00:24,  4.01it/s]
#   4% 4/100 [00:01<00:28,  3.42it/s]
#   5% 5/100 [00:01<00:27,  3.44it/s]
#   6% 6/100 [00:01<00:32,  2.93it/s]
#   7% 7/100 [00:02<00:31,  2.97it/s]
#   8% 8/100 [00:02<00:33,  2.76it/s]
#   9% 9/100 [00:02<00:35,  2.59it/s]
#  10% 10/100 [00:03<00:34,  2.61it/s]
#  11% 11/100 [00:03<00:34,  2.61it/s]
#  12% 12/100 [00:03<00:30,  2.91it/s]
#  13% 13/100 [00:04<00:32,  2.64it/s]
#  14% 14/100 [00:04<00:36,  2.36it/s]
#  15% 15/100 [00:05<00:39,  2.15it/s]
#  73% 73/100 [00:33<00:11,  2.32it/s]
#  74% 74/100 [00:34<00:10,  2.42it/s]
#  75% 75/100 [00:34<00:09,  2.56it/s]
#  76% 76/100 [00:34<00:08,  2.76it/s]
#  77% 77/100 [00:35<00:08,  2.75it/s]
#  78% 78/100 [00:35<00:08,  2.58it/s]
#  79% 79/100 [00:35<00:07,  2.67it/s]
#  80% 80/100 [00:36<00:07,  2.73it/s]
#  81% 81/100 [00:36<00:07,  2.59it/s]
#  82% 82/100 [00:36<00:06,  2.74it/s]
#  83% 83/100 [00:37<00:06,  2.57it/s]
#  84% 84/100 [00:37<00:06,  2.40it/s]
#  85% 85/100 [00:38<00:06,  2.50it/s]
#  86% 86/100 [00:38<00:05,  2.47it/s]
#  87% 87/100 [00:39<00:05,  2.55it/s]
#  88% 88/100 [00:39<00:04,  2.53it/s]
#  89% 89/100 [00:39<00:04,  2.63it/s]
#  90% 90/100 [00:40<00:03,  2.52it/s]
#  91% 91/100 [00:40<00:03,  2.45it/s]
#  92% 92/100 [00:41<00:03,  2.57it/s]
#  93% 93/100 [00:41<00:02,  2.51it/s]
#  94% 94/100 [00:41<00:02,  2.47it/s]
#  95% 95/100 [00:42<00:02,  2.19it/s]
#  96% 96/100 [00:42<00:01,  2.20it/s]
#  97% 97/100 [00:43<00:01,  2.01it/s]
#  98% 98/100 [00:43<00:00,  2.02it/s]
#  99% 99/100 [00:44<00:00,  2.05it/s]
#
# {'eval_loss': 0.6170995235443115, 'eval_rouge1': 72.0943, 'eval_rouge2': 53.5257, 'eval_rougeL': 69.261, 'eval_rougeLsum': 69.3295, 'eval_gen_len': 13.295, 'eval_runtime': 46.0453, 'eval_samples_per_second': 4.344, 'eval_steps_per_second': 2.172, 'epoch': 12.5}
#  17% 2500/15000 [16:32<50:43,  4.11it/s]
# 100% 100/100 [00:45<00:00,  1.86it/s]
#                                      [INFO|trainer.py:2875] 2023-04-30 08:31:25,484 >> Saving model checkpoint to output-T5/checkpoint-2500
# [INFO|configuration_utils.py:458] 2023-04-30 08:31:25,485 >> Configuration saved in output-T5/checkpoint-2500/config.json
# [INFO|configuration_utils.py:364] 2023-04-30 08:31:25,486 >> Configuration saved in output-T5/checkpoint-2500/generation_config.json
# [INFO|modeling_utils.py:1855] 2023-04-30 08:31:28,604 >> Model weights saved in output-T5/checkpoint-2500/pytorch_model.bin
# [INFO|tokenization_utils_base.py:2181] 2023-04-30 08:31:28,605 >> tokenizer config file saved in output-T5/checkpoint-2500/tokenizer_config.json
# [INFO|tokenization_utils_base.py:2188] 2023-04-30 08:31:28,606 >> Special tokens file saved in output-T5/checkpoint-2500/special_tokens_map.json
# [INFO|tokenization_t5_fast.py:186] 2023-04-30 08:31:28,681 >> Copy vocab file to output-T5/checkpoint-2500/spiece.model
# {'loss': 0.4459, 'learning_rate': 8.000000000000001e-06, 'epoch': 15.0}
#  20% 3000/15000 [19:05<1:10:34,  2.83it/s][INFO|trainer.py:3136] 2023-04-30 08:33:58,640 >> ***** Running Evaluation *****
# [INFO|trainer.py:3138] 2023-04-30 08:33:58,640 >>   Num examples = 200
# [INFO|trainer.py:3141] 2023-04-30 08:33:58,640 >>   Batch size = 2
#
#   0% 0/100 [00:00<?, ?it/s]
#   2% 2/100 [00:00<00
#  62% 62/100 [00:26<00:15,  2.42it/s]
#  63% 63/100 [00:26<00:16,  2.30it/s]
#  64% 64/100 [00:27<00:15,  2.36it/s]
#  65% 65/100 [00:27<00:13,  2.64it/s]
#  66% 66/100 [00:27<00:13,  2.59it/s]
#  67% 67/100 [00:28<00:11,  2.85it/s]
#  68% 68/100 [00:28<00:10,  2.93it/s]
#  69% 69/100 [00:28<00:10,  2.84it/s]
#  70% 70/100 [00:29<00:10,  2.84it/s]
#  71% 71/100 [00:29<00:11,  2.60it/s]
#  72% 72/100 [00:30<00:11,  2.38it/s]
#  73% 73/100 [00:30<00:12,  2.13it/s]
#  74% 74/100 [00:31<00:12,  2.07it/s]
#  75% 75/100 [00:31<00:11,  2.15it/s]
#  76% 76/100 [00:32<00:10,  2.28it/s]
#  77% 77/100 [00:32<00:10,  2.21it/s]
#  78% 78/100 [00:33<00:11,  2.00it/s]
#  79% 79/100 [00:33<00:10,  1.92it/s]
#  80% 80/100 [00:34<00:10,  1.87it/s]
#  81% 81/100 [00:35<00:11,  1.67it/s]
#  82% 82/100 [00:35<00:10,  1.76it/s]
#  83% 83/100 [00:36<00:09,  1.82it/s]
#  84% 84/100 [00:36<00:09,  1.60it/s]
#  85% 85/100 [00:37<00:08,  1.67it/s]
#  86% 86/100 [00:37<00:08,  1.65it/s]
#  87% 87/100 [00:38<00:06,  1.89it/s]
#  88% 88/100 [00:38<00:05,  2.07it/s]
#  89% 89/100 [00:39<00:04,  2.28it/s]
#  90% 90/100 [00:39<00:04,  2.29it/s]
#  91% 91/100 [00:39<00:03,  2.29it/s]
#  92% 92/100 [00:40<00:03,  2.46it/s]
#  93% 93/100 [00:40<00:02,  2.48it/s]
#  94% 94/100 [00:40<00:02,  2.66it/s]
#  95% 95/100 [00:41<00:01,  2.73it/s]
#  96% 96/100 [00:41<00:01,  2.78it/s]
#  97% 97/100 [00:42<00:01,  2.66it/s]
#  98% 98/100 [00:42<00:00,  2.73it/s]
#  99% 99/100 [00:42<00:00,  2.80it/s]
#
# {'eval_loss': 0.6002472639083862, 'eval_rouge1': 73.858, 'eval_rouge2': 57.0851, 'eval_rougeL': 70.9994, 'eval_rougeLsum': 71.0763, 'eval_gen_len': 12.98, 'eval_runtime': 44.0447, 'eval_samples_per_second': 4.541, 'eval_steps_per_second': 2.27, 'epoch': 15.0}
#  20% 3000/15000 [19:49<1:10:34,  2.83it/s]
# 100% 100/100 [00:43<00:00,  2.57it/s]
#                                      [INFO|trainer.py:2875] 2023-04-30 08:34:42,686 >> Saving model checkpoint to output-T5/checkpoint-3000
# [INFO|configuration_utils.py:458] 2023-04-30 08:34:42,687 >> Configuration saved in output-T5/checkpoint-3000/config.json
# [INFO|configuration_utils.py:364] 2023-04-30 08:34:42,687 >> Configuration saved in output-T5/checkpoint-3000/generation_config.json
# [INFO|modeling_utils.py:1855] 2023-04-30 08:34:45,747 >> Model weights saved in output-T5/checkpoint-3000/pytorch_model.bin
# [INFO|tokenization_utils_base.py:2181] 2023-04-30 08:34:45,748 >> tokenizer config file saved in output-T5/checkpoint-3000/tokenizer_config.json
# [INFO|tokenization_utils_base.py:2188] 2023-04-30 08:34:45,748 >> Special tokens file saved in output-T5/checkpoint-3000/special_tokens_map.json
# [INFO|tokenization_t5_fast.py:186] 2023-04-30 08:34:45,787 >> Copy vocab file to output-T5/checkpoint-3000/spiece.model
# {'loss': 0.398, 'learning_rate': 7.666666666666667e-06, 'epoch': 17.5}
#  23% 3500/15000 [22:22<46:57,  4.08it/s][INFO|trainer.py:3136] 2023-04-30 08:37:15,673 >> ***** Running Evaluation *****
# [INFO|trainer.py:3138] 2023-04-30 08:37:15,673 >>   Num examples = 200
# [INFO|trainer.py:3141] 2023-04-30 08:37:15,673 >>   Batch size = 2
#
#   0% 0/100 [00:00<?, ?it/s]
#   2% 2/100 [00:00<00:15,  6.43it/s]
# ...
#  79% 79/100 [00:35<00:07,  2.78it/s]
#  80% 80/100 [00:36<00:06,  2.90it/s]
#  81% 81/100 [00:36<00:07,  2.47it/s]
#  82% 82/100 [00:37<00:07,  2.47it/s]
#  83% 83/100 [00:37<00:06,  2.51it/s]
#  84% 84/100 [00:38<00:07,  2.05it/s]
#  85% 85/100 [00:38<00:07,  2.12it/s]
#  86% 86/100 [00:39<00:06,  2.16it/s]
#  87% 87/100 [00:39<00:06,  2.07it/s]
#  88% 88/100 [00:40<00:06,  1.85it/s]
#  89% 89/100 [00:41<00:07,  1.57it/s]
#  90% 90/100 [00:41<00:06,  1.54it/s]
#  91% 91/100 [00:42<00:06,  1.41it/s]
#  92% 92/100 [00:43<00:05,  1.51it/s]
#  93% 93/100 [00:43<00:04,  1.53it/s]
#  94% 94/100 [00:44<00:03,  1.63it/s]
#  95% 95/100 [00:44<00:02,  1.67it/s]
#  96% 96/100 [00:45<00:02,  1.91it/s]
#  97% 97/100 [00:45<00:01,  2.08it/s]
#  98% 98/100 [00:45<00:00,  2.21it/s]
#  99% 99/100 [00:46<00:00,  2.38it/s]
#
# {'eval_loss': 0.5627560615539551, 'eval_rouge1': 78.1148, 'eval_rouge2': 65.0006, 'eval_rougeL': 76.2674, 'eval_rougeLsum': 76.3265, 'eval_gen_len': 12.975, 'eval_runtime': 47.6988, 'eval_samples_per_second': 4.193, 'eval_steps_per_second': 2.096, 'epoch': 70.0}
#  93% 14000/15000 [1:33:19<04:44,  3.51it/s]
# 100% 100/100 [00:47<00:00,  2.12it/s]
#                                      [INFO|trainer.py:2875] 2023-04-30 09:48:13,286 >> Saving model checkpoint to output-T5/checkpoint-14000
# [INFO|configuration_utils.py:458] 2023-04-30 09:48:13,287 >> Configuration saved in output-T5/checkpoint-14000/config.json
# [INFO|configuration_utils.py:364] 2023-04-30 09:48:13,287 >> Configuration saved in output-T5/checkpoint-14000/generation_config.json
# [INFO|modeling_utils.py:1855] 2023-04-30 09:48:16,290 >> Model weights saved in output-T5/checkpoint-14000/pytorch_model.bin
# [INFO|tokenization_utils_base.py:2181] 2023-04-30 09:48:16,291 >> tokenizer config file saved in output-T5/checkpoint-14000/tokenizer_config.json
# [INFO|tokenization_utils_base.py:2188] 2023-04-30 09:48:16,292 >> Special tokens file saved in output-T5/checkpoint-14000/special_tokens_map.json
# [INFO|tokenization_t5_fast.py:186] 2023-04-30 09:48:16,334 >> Copy vocab file to output-T5/checkpoint-14000/spiece.model
# {'loss': 0.1285, 'learning_rate': 3.3333333333333335e-07, 'epoch': 72.5}
#  97% 14500/15000 [1:35:54<02:16,  3.65it/s][INFO|trainer.py:3136] 2023-04-30 09:50:47,757 >> ***** Running Evaluation *****
# [INFO|trainer.py:3138] 2023-04-30 09:50:47,758 >>   Num examples = 200
# [INFO|trainer.py:3141] 2023-04-30 09:50:47,758 >>   Batch size = 2
#
#   0% 0/100 [00:00<?, ?it/s]
#   2% 2/100 [00:00<00
#  57% 57/100 [00:25<00:18,  2.31it/s]
#  58% 58/100 [00:25<00:18,  2.28it/s]
#  59% 59/100 [00:26<00:17,  2.34it/s]
#  60% 60/100 [00:26<00:16,  2.47it/s]
#  61% 61/100 [00:27<00:16,  2.38it/s]
#  62% 62/100 [00:27<00:18,  2.08it/s]
#  63% 63/100 [00:28<00:18,  1.95it/s]
#  64% 64/100 [00:28<00:18,  1.93it/s]
#  65% 65/100 [00:29<00:16,  2.08it/s]
#  66% 66/100 [00:29<00:17,  1.89it/s]
#  67% 67/100 [00:30<00:15,  2.11it/s]
#  68% 68/100 [00:30<00:15,  2.12it/s]
#  69% 69/100 [00:31<00:15,  1.95it/s]
#  70% 70/100 [00:31<00:16,  1.83it/s]
#  71% 71/100 [00:32<00:15,  1.85it/s]
#  72% 72/100 [00:33<00:16,  1.73it/s]
#  73% 73/100 [00:33<00:17,  1.59it/s]
#  74% 74/100 [00:34<00:15,  1.67it/s]
#  75% 75/100 [00:34<00:14,  1.69it/s]
#  76% 76/100 [00:35<00:13,  1.78it/s]
#  77% 77/100 [00:35<00:13,  1.73it/s]
#  78% 78/100 [00:36<00:12,  1.82it/s]
#  79% 79/100 [00:36<00:10,  2.02it/s]
#  80% 80/100 [00:37<00:08,  2.33it/s]
#  81% 81/100 [00:37<00:08,  2.35it/s]
#  82% 82/100 [00:37<00:07,  2.44it/s]
#  83% 83/100 [00:38<00:06,  2.65it/s]
#  84% 84/100 [00:38<00:06,  2.34it/s]
#  85% 85/100 [00:39<00:06,  2.48it/s]
#  86% 86/100 [00:39<00:05,  2.62it/s]
#  87% 87/100 [00:39<00:04,  2.63it/s]
#  88% 88/100 [00:40<00:04,  2.56it/s]
#  89% 89/100 [00:40<00:04,  2.26it/s]
#  90% 90/100 [00:41<00:04,  2.23it/s]
#  91% 91/100 [00:41<00:04,  2.09it/s]
#  92% 92/100 [00:42<00:03,  2.29it/s]
#  93% 93/100 [00:42<00:02,  2.37it/s]
#  94% 94/100 [00:42<00:02,  2.52it/s]
#  95% 95/100 [00:43<00:02,  2.47it/s]
#  96% 96/100 [00:43<00:01,  2.56it/s]
#  97% 97/100 [00:44<00:01,  2.50it/s]
#  98% 98/100 [00:44<00:00,  2.53it/s]
#  99% 99/100 [00:44<00:00,  2.64it/s]
#
# {'eval_loss': 0.563203752040863, 'eval_rouge1': 78.6412, 'eval_rouge2': 65.6938, 'eval_rougeL': 76.8819, 'eval_rougeLsum': 77.0105, 'eval_gen_len': 13.03, 'eval_runtime': 46.052, 'eval_samples_per_second': 4.343, 'eval_steps_per_second': 2.171, 'epoch': 72.5}
#  97% 14500/15000 [1:36:40<02:16,  3.65it/s]
# 100% 100/100 [00:45<00:00,  2.27it/s]
#                                      [INFO|trainer.py:2875] 2023-04-30 09:51:33,811 >> Saving model checkpoint to output-T5/checkpoint-14500
# [INFO|configuration_utils.py:458] 2023-04-30 09:51:33,813 >> Configuration saved in output-T5/checkpoint-14500/config.json
# [INFO|configuration_utils.py:364] 2023-04-30 09:51:33,813 >> Configuration saved in output-T5/checkpoint-14500/generation_config.json
# [INFO|modeling_utils.py:1855] 2023-04-30 09:51:36,834 >> Model weights saved in output-T5/checkpoint-14500/pytorch_model.bin
# [INFO|tokenization_utils_base.py:2181] 2023
# {'eval_loss': 0.5638355016708374, 'eval_rouge1': 78.9186, 'eval_rouge2': 65.957, 'eval_rougeL': 77.1226, 'eval_rougeLsum': 77.23, 'eval_gen_len': 13.075, 'eval_runtime': 47.1421, 'eval_samples_per_second': 4.242, 'eval_steps_per_second': 2.121, 'epoch': 75.0}
# 100% 15000/15000 [1:40:02<00:00,  4.02it/s]
# 100% 100/100 [00:46<00:00,  1.60it/s]
#                                      [INFO|trainer.py:2875] 2023-04-30 09:54:56,184 >> Saving model checkpoint to output-T5/checkpoint-15000
# [INFO|configuration_utils.py:458] 2023-04-30 09:54:56,186 >> Configuration saved in output-T5/checkpoint-15000/config.json
# [INFO|configuration_utils.py:364] 2023-04-30 09:54:56,186 >> Configuration saved in output-T5/checkpoint-15000/generation_config.json
# [INFO|modeling_utils.py:1855] 2023-04-30 09:54:59,314 >> Model weights saved in output-T5/checkpoint-15000/pytorch_model.bin
# [INFO|tokenization_utils_base.py:2181] 2023-04-30 09:54:59,315 >> tokenizer config file saved in output-T5/checkpoint-15000/tokenizer_config.json
# [INFO|tokenization_utils_base.py:2188] 2023-04-30 09:54:59,315 >> Special tokens file saved in output-T5/checkpoint-15000/special_tokens_map.json
# [INFO|tokenization_t5_fast.py:186] 2023-04-30 09:54:59,400 >> Copy vocab file to output-T5/checkpoint-15000/spiece.model
# [INFO|trainer.py:2042] 2023-04-30 09:55:06,417 >>
#
# Training completed. Do not forget to share your model on huggingface.co/models =)
#
#
# [INFO|trainer.py:2175] 2023-04-30 09:55:06,417 >> Loading best model from output-T5/checkpoint-9500 (score: 0.5405018925666809).
# {'train_runtime': 6017.6408, 'train_samples_per_second': 9.971, 'train_steps_per_second': 2.493, 'train_loss': 0.3099613235473633, 'epoch': 75.0}
# 100% 15000/15000 [1:40:17<00:00,  2.49it/s]
# [INFO|trainer.py:2875] 2023-04-30 09:55:10,942 >> Saving model checkpoint to output-T5
# [INFO|configuration_utils.py:458] 2023-04-30 09:55:10,943 >> Configuration saved in output-T5/config.json
# [INFO|configuration_utils.py:364] 2023-04-30 09:55:10,944 >> Configuration saved in output-T5/generation_config.json
# [INFO|modeling_utils.py:1855] 2023-04-30 09:55:14,035 >> Model weights saved in output-T5/pytorch_model.bin
# [INFO|tokenization_utils_base.py:2181] 2023-04-30 09:55:14,088 >> tokenizer config file saved in output-T5/tokenizer_config.json
# [INFO|tokenization_utils_base.py:2188] 2023-04-30 09:55:14,088 >> Special tokens file saved in output-T5/special_tokens_map.json
# [INFO|tokenization_t5_fast.py:186] 2023-04-30 09:55:14,216 >> Copy vocab file to output-T5/spiece.model
# ***** train metrics *****
#   epoch                    =       75.0
#   train_loss               =       0.31
#   train_runtime            = 1:40:17.64
#   train_samples            =        800
#   train_samples_per_second =      9.971
#   train_steps_per_second   =      2.493
# 04/30/2023 09:55:14 - INFO - __main__ - *** Evaluate ***
# [INFO|trainer.py:3136] 2023-04-30 09:55:14,235 >> ***** Running Evaluation *****
# [INFO|trainer.py:3138] 2023-04-30 09:55:14,235 >>   Num examples = 200
# [INFO|trainer.py:3141] 2023-04-30 09:55:14,235 >>   Batch size = 2
# 100% 100/100 [00:47<00:00,  2.11it/s]
# ***** eval metrics *****
#   epoch                   =       75.0
#   eval_gen_len            =      13.06
#   eval_loss               =     0.5405
#   eval_rouge1             =    78.3404
#   eval_rouge2             =    64.9119
#   eval_rougeL             =    76.4256
#   eval_rougeLsum          =    76.4988
#   eval_runtime            = 0:00:47.99
#   eval_samples            =        200
#   eval_samples_per_second =      4.167
#   eval_steps_per_second   =      2.083
# 04/30/2023 09:56:02 - INFO - __main__ - *** Predict ***
# [INFO|trainer.py:3136] 2023-04-30 09:56:02,237 >> ***** Running Prediction *****
# [INFO|trainer.py:3138] 2023-04-30 09:56:02,237 >>   Num examples = 200
# [INFO|trainer.py:3141] 2023-04-30 09:56:02,237 >>   Batch size = 2
# 100% 100/100 [00:44<00:00,  2.23it/s]
# ***** predict metrics *****
#   predict_gen_len            =      13.06
#   predict_loss               =     0.5405
#   predict_rouge1             =    78.3404
#   predict_rouge2             =    64.9119
#   predict_rougeL             =    76.4256
#   predict_rougeLsum          =    76.4988
#   predict_runtime            = 0:00:45.25
#   predict_samples            =        200
#   predict_samples_per_second =       4.42
#   predict_steps_per_second   =       2.21
# [INFO|modelcard.py:451] 2023-04-30 09:56:47,795 >> Dropping the following result as it does not have all the necessary fields:
# {'task': {'name': 'Summarization', 'type': 'summarization'}, 'metrics': [{'name': 'Rouge1', 'type': 'rouge', 'value': 78.3404}]}

# %%
# !rm -r /content/transformers/examples/pytorch/summarization/output-T5/checkpoint-75

# %%
# resume training
# !python3 run_summarization.py \
    --model_name_or_path t5-base \
    --do_train \
    --do_eval \
    --do_predict \
    --train_file 'train_merge.csv' \
    --validation_file 'test.csv' \
    --test_file 'test.csv' \
    --text_column text \
    --summary_column headlines \
    --source_prefix "generate a math question from context: " \
    --output_dir  'output-T5' \
    --logging_dir  'output-T5' \
    --per_device_train_batch_size=2 \
    --per_device_eval_batch_size=2 \
    --gradient_accumulation_steps=2 \
    --predict_with_generate=True \
    --learning_rate=0.00001 \
    --num_beams=5 \
    --max_steps=15000 \
    --save_steps=500 \
    --eval_steps=500 \
    --evaluation_strategy steps \
    --load_best_model

# %%
# !cp -r /content/transformers/examples/pytorch/summarization/output-T5/checkpoint-13500 /content/drive/MyDrive/SVAMP_TEMP

# %%
# %cd /content/transformers/examples/pytorch/summarization/output-T5
# !cp all_results.json /content/drive/MyDrive/SVAMP_TEMP
# !cp README.md /content/drive/MyDrive/SVAMP_TEMP
# !cp eval_results.json /content/drive/MyDrive/SVAMP_TEMP
# !cp generated_predictions.txt /content/drive/MyDrive/SVAMP_TEMP
# !cp generation_config.json /content/drive/MyDrive/SVAMP_TEMP
# !cp predict_results.json /content/drive/MyDrive/SVAMP_TEMP
# !cp special_tokens_map.json /content/drive/MyDrive/SVAMP_TEMP
# !cp spiece.model /content/drive/MyDrive/SVAMP_TEMP
# !cp tokenizer.json /content/drive/MyDrive/SVAMP_TEMP
# !cp train_results.json /content/drive/MyDrive/SVAMP_TEMP
# !cp trainer_state.json /content/drive/MyDrive/SVAMP_TEMP
# !cp training_args.bin /content/drive/MyDrive/SVAMP_TEMP
# !cp pytorch_model.bin /content/drive/MyDrive/SVAMP_TEMP
# !cp 'events.out.tfevents.1682842493.4f58f4c95b04.1337.0' /content/drive/MyDrive/SVAMP_TEMP
# !cp 'events.out.tfevents.1682848562.4f58f4c95b04.1337.2' /content/drive/MyDrive/SVAMP_TEMP
# Out:
# /content/transformers/examples/pytorch/summarization/output-T5

# %%
# !cp /content/transformers/examples/pytorch/summarization/output-T5/pytorch_model.bin
